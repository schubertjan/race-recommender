# %%
import requests 
import time

import pandas as pd
import numpy as np

from bs4 import BeautifulSoup

# %%
def clean_df(df, race, year):
  for index, row in df.iterrows():
    # clean rider names
    df.loc[index, "Rider"] = row["Rider"].replace(row["Team"], "")
    # make sure we have 0 when participated and NaN when not participated
    if (~row[["Rnk"]].isin(["DNF", "DNS"])[0]) & row[["UCI"]].isna()[0]:
      df.loc[index, "UCI"] = 0
    
    # extract info
  df2 = df[["Rider", "UCI"]]
          # add meta data
  df2["Race"] = race.replace("race/", "").replace(f"/{year}", "").replace(f"-{year}", "")
  df2["Year"] = year
  return df2

def extract_stage_urls(r):
  soup = BeautifulSoup(r.content)
  hrefs = [line.get("href") for line in soup.select("a")]
  hrefs = [href for href in hrefs if href is not None]
  hrefs = [href for href in hrefs if href.find("stage-") > 0]
  last_stage = [href for href in hrefs if len(re.findall(r'\d+$', href)) > 0][0]

  last_stage_number = int(last_stage.split("-")[-1])
  stage_numbers = np.arange(1,last_stage_number + 1)

  stage_urls = []
  for stage_num in stage_numbers:
    stage_urls.append("-".join(last_stage.split("-")[:-1] + [str(stage_num)]))
  return stage_urls

def extract_results(year: str, circuit: int) -> pd.DataFrame:

  header = {
    "User-Agent": "Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/50.0.2661.75 Safari/537.36",
    "X-Requested-With": "XMLHttpRequest"
  }

  base_url = "https://www.procyclingstats.com/"
  r = requests.get(f"{base_url}races.php?year={year}&circuit={circuit}&class=&filter=Filter", headers=header)

  soup = BeautifulSoup(r.content)

  href = []

  for line in soup.find_all('a'):
      href.append(line.get('href'))
    
  race_url = [line for line in href if line.find("race/") == 0]
  race_url = [line for line in race_url if line.find(year) == (len(line)-4)]

  results = []

  for race in race_url:
    # dont use nc
    if ("nc-" in race) | ("national-championships" in race):
      print(f"NC race: {race}")
    else:  
      try:
        r = requests.get(base_url + race, headers=header)
        time.sleep(3)
        result = pd.read_html(r.text)[0]
        if "GC" not in result.columns:
          # do some data cleaning
          result = clean_df(result, race, year)
          results.append(result)
          print(f"Extracting 1day race:: {race}")
        else:
          stage_urls = extract_stage_urls(r)
          stages = []
          # extract results for all stages and sum
          for stage_url in stage_urls:
            print(f"Extracting stage race: {stage_url}")
            r_stage = requests.get(base_url + stage_url, headers=header)
            time.sleep(3)
            stage_df = pd.read_html(r_stage.text)[0]
            stages.append(clean_df(stage_df, race, year))
          stages_df = pd.concat(stages)
          stage_summary = stages_df.groupby(["Rider", "Race", "Year"], as_index=False)["UCI"].sum()[["Rider", "UCI", "Race", "Year"]]
          results.append(stage_summary)
      except:
        print(f"Extraction failed: {race}")
    
  return pd.concat(results)

# %%
years = ["2020", "2021", "2022"]
circuits = [1, 13]
results = []
for year in years:
  for circuit in circuits:
    try: 
      results.append(extract_results(year=year, circuit=circuit))
    except:
      pass
# Out:
# Extracting stage race: race/tour-down-under/2020/stage-1
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   if sys.path[0] == '':
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   del sys.path[0]
# Extracting stage race: race/tour-down-under/2020/stage-2
# Extracting stage race: race/tour-down-under/2020/stage-3
# Extracting stage race: race/tour-down-under/2020/stage-4
# Extracting stage race: race/tour-down-under/2020/stage-5
# Extracting stage race: race/tour-down-under/2020/stage-6
# Extracting 1day race:: race/great-ocean-race/2020
# Extracting stage race: race/uae-tour/2020/stage-1
# Extracting stage race: race/uae-tour/2020/stage-2
# Extracting stage race: race/uae-tour/2020/stage-3
# Extracting stage race: race/uae-tour/2020/stage-4
# Extracting stage race: race/uae-tour/2020/stage-5
# Extracting 1day race:: race/omloop-het-nieuwsblad/2020
# Extracting stage race: race/paris-nice/2020/stage-1
# Extracting stage race: race/paris-nice/2020/stage-2
# Extracting stage race: race/paris-nice/2020/stage-3
# Extracting stage race: race/paris-nice/2020/stage-4
# Extracting stage race: race/paris-nice/2020/stage-5
# Extracting stage race: race/paris-nice/2020/stage-6
# Extracting stage race: race/paris-nice/2020/stage-7
# Extracting 1day race:: race/strade-bianche/2020
# Extracting stage race: race/tour-de-pologne/2020/stage-1
# Extracting stage race: race/tour-de-pologne/2020/stage-2
# Extracting stage race: race/tour-de-pologne/2020/stage-3
# Extracting stage race: race/tour-de-pologne/2020/stage-4
# Extracting stage race: race/tour-de-pologne/2020/stage-5
# Extracting 1day race:: race/milano-sanremo/2020
# Extracting stage race: race/dauphine/2020/stage-1
# Extracting stage race: race/dauphine/2020/stage-2
# Extracting stage race: race/dauphine/2020/stage-3
# Extracting stage race: race/dauphine/2020/stage-4
# Extracting stage race: race/dauphine/2020/stage-5
# Extracting 1day race:: race/il-lombardia/2020
# Extracting 1day race:: race/bretagne-classic/2020
# Extracting stage race: race/tour-de-france/2020/stage-1
# Extracting stage race: race/tour-de-france/2020/stage-2
# Extracting stage race: race/tour-de-france/2020/stage-3
# Extracting stage race: race/tour-de-france/2020/stage-4
# Extracting stage race: race/tour-de-france/2020/stage-5
# Extracting stage race: race/tour-de-france/2020/stage-6
# Extracting stage race: race/tour-de-france/2020/stage-7
# Extracting stage race: race/tour-de-france/2020/stage-8
# Extracting stage race: race/tour-de-france/2020/stage-9
# Extracting stage race: race/tour-de-france/2020/stage-10
# Extracting stage race: race/tour-de-france/2020/stage-11
# Extracting stage race: race/tour-de-france/2020/stage-12
# Extracting stage race: race/tour-de-france/2020/stage-13
# Extracting stage race: race/tour-de-france/2020/stage-14
# Extracting stage race: race/tour-de-france/2020/stage-15
# Extracting stage race: race/tour-de-france/2020/stage-16
# Extracting stage race: race/tour-de-france/2020/stage-17
# Extracting stage race: race/tour-de-france/2020/stage-18
# Extracting stage race: race/tour-de-france/2020/stage-19
# Extracting stage race: race/tour-de-france/2020/stage-20
# Extracting stage race: race/tour-de-france/2020/stage-21
# Extracting stage race: race/tirreno-adriatico/2020/stage-1
# Extracting stage race: race/tirreno-adriatico/2020/stage-2
# Extracting stage race: race/tirreno-adriatico/2020/stage-3
# Extracting stage race: race/tirreno-adriatico/2020/stage-4
# Extracting stage race: race/tirreno-adriatico/2020/stage-5
# Extracting stage race: race/tirreno-adriatico/2020/stage-6
# Extracting stage race: race/tirreno-adriatico/2020/stage-7
# Extracting stage race: race/tirreno-adriatico/2020/stage-8
# Extracting stage race: race/benelux-tour/2020/stage-1
# Extracting stage race: race/benelux-tour/2020/stage-2
# Extracting stage race: race/benelux-tour/2020/stage-3
# Extracting stage race: race/benelux-tour/2020/stage-4
# Extracting stage race: race/benelux-tour/2020/stage-5
# Extracting 1day race:: race/la-fleche-wallone/2020
# Extracting stage race: race/giro-d-italia/2020/stage-1
# Extracting stage race: race/giro-d-italia/2020/stage-2
# Extracting stage race: race/giro-d-italia/2020/stage-3
# Extracting stage race: race/giro-d-italia/2020/stage-4
# Extracting stage race: race/giro-d-italia/2020/stage-5
# Extracting stage race: race/giro-d-italia/2020/stage-6
# Extracting stage race: race/giro-d-italia/2020/stage-7
# Extracting stage race: race/giro-d-italia/2020/stage-8
# Extracting stage race: race/giro-d-italia/2020/stage-9
# Extracting stage race: race/giro-d-italia/2020/stage-10
# Extracting stage race: race/giro-d-italia/2020/stage-11
# Extracting stage race: race/giro-d-italia/2020/stage-12
# Extracting stage race: race/giro-d-italia/2020/stage-13
# Extracting stage race: race/giro-d-italia/2020/stage-14
# Extracting stage race: race/giro-d-italia/2020/stage-15
# Extracting stage race: race/giro-d-italia/2020/stage-16
# Extracting stage race: race/giro-d-italia/2020/stage-17
# Extracting stage race: race/giro-d-italia/2020/stage-18
# Extracting stage race: race/giro-d-italia/2020/stage-19
# Extracting stage race: race/giro-d-italia/2020/stage-20
# Extracting stage race: race/giro-d-italia/2020/stage-21
# Extracting 1day race:: race/liege-bastogne-liege/2020
# Extracting 1day race:: race/gent-wevelgem/2020
# Extracting 1day race:: race/ronde-van-vlaanderen/2020
# Extracting stage race: race/vuelta-a-espana/2020/stage-1
# Extracting stage race: race/vuelta-a-espana/2020/stage-2
# Extracting stage race: race/vuelta-a-espana/2020/stage-3
# Extracting stage race: race/vuelta-a-espana/2020/stage-4
# Extracting stage race: race/vuelta-a-espana/2020/stage-5
# Extracting stage race: race/vuelta-a-espana/2020/stage-6
# Extracting stage race: race/vuelta-a-espana/2020/stage-7
# Extracting stage race: race/vuelta-a-espana/2020/stage-8
# Extracting stage race: race/vuelta-a-espana/2020/stage-9
# Extracting stage race: race/vuelta-a-espana/2020/stage-10
# Extracting stage race: race/vuelta-a-espana/2020/stage-11
# Extracting stage race: race/vuelta-a-espana/2020/stage-12
# Extracting stage race: race/vuelta-a-espana/2020/stage-13
# Extracting stage race: race/vuelta-a-espana/2020/stage-14
# Extracting stage race: race/vuelta-a-espana/2020/stage-15
# Extracting stage race: race/vuelta-a-espana/2020/stage-16
# Extracting stage race: race/vuelta-a-espana/2020/stage-17
# Extracting stage race: race/vuelta-a-espana/2020/stage-18
# Extracting 1day race:: race/oxyclean-classic-brugge-de-panne/2020
# Extracting 1day race:: race/gp-belek/2020
# Extracting 1day race:: race/trofeo-cala-millor/2020
# Extracting 1day race:: race/deia-trophy/2020
# Extracting 1day race:: race/trofeo-andratx-mirador-d-es-colomer/2020
# Extracting 1day race:: race/gp-d-ouverture/2020
# Extracting 1day race:: race/trofeo-palma/2020
# Extracting stage race: race/vuelta-a-la-comunidad-valenciana/2020/stage-1
# Extracting stage race: race/vuelta-a-la-comunidad-valenciana/2020/stage-2
# Extracting stage race: race/vuelta-a-la-comunidad-valenciana/2020/stage-3
# Extracting stage race: race/vuelta-a-la-comunidad-valenciana/2020/stage-4
# Extracting stage race: race/vuelta-a-la-comunidad-valenciana/2020/stage-5
# Extracting stage race: race/etoile-de-besseges/2020/stage-1
# Extracting stage race: race/etoile-de-besseges/2020/stage-2
# Extracting stage race: race/etoile-de-besseges/2020/stage-3
# Extracting stage race: race/etoile-de-besseges/2020/stage-4
# Extracting stage race: race/etoile-de-besseges/2020/stage-5
# Extracting 1day race:: race/gp-manavgat/2020
# Extracting stage race: race/tour-cycliste-international-la-provence/2020/stage-1
# Extracting stage race: race/tour-cycliste-international-la-provence/2020/stage-2
# Extracting stage race: race/tour-cycliste-international-la-provence/2020/stage-3
# Extracting stage race: race/tour-cycliste-international-la-provence/2020/stage-4
# Extracting 1day race:: race/grand-prix-alanya/2020
# Extracting stage race: race/vuelta-ciclista-a-la-region-de-murcia/2020/stage-1
# Extracting stage race: race/vuelta-ciclista-a-la-region-de-murcia/2020/stage-2
# Extracting 1day race:: race/grand-prix-gazipasa/2020
# Extracting 1day race:: race/clasica-de-almeria/2020
# Extracting 1day race:: race/trofeo-laigueglia/2020
# Extracting 1day race:: race/gp-antalya/2020
# Extracting stage race: race/volta-ao-algarve/2020/stage-1
# Extracting stage race: race/volta-ao-algarve/2020/stage-2
# Extracting stage race: race/volta-ao-algarve/2020/stage-3
# Extracting stage race: race/volta-ao-algarve/2020/stage-4
# Extracting stage race: race/volta-ao-algarve/2020/stage-5
# Extracting stage race: race/ruta-del-sol/2020/stage-1
# Extracting stage race: race/ruta-del-sol/2020/stage-2
# Extracting stage race: race/ruta-del-sol/2020/stage-3
# Extracting stage race: race/ruta-del-sol/2020/stage-4
# Extracting stage race: race/ruta-del-sol/2020/stage-5
# Extracting stage race: race/tour-of-antalya/2020/stage-1
# Extracting stage race: race/tour-of-antalya/2020/stage-2
# Extracting stage race: race/tour-of-antalya/2020/stage-3
# Extracting stage race: race/tour-of-antalya/2020/stage-4
# Extracting stage race: race/tour-des-alpes-maritimes-et-du-var/2020/stage-1
# Extracting stage race: race/tour-des-alpes-maritimes-et-du-var/2020/stage-2
# Extracting stage race: race/tour-des-alpes-maritimes-et-du-var/2020/stage-3
# Extracting stage race: race/manavgat-side-junior/2020/stage-1
# Extraction failed: race/manavgat-side-junior/2020
# Extracting 1day race:: race/faun-ardeche-classic/2020
# Extracting 1day race:: race/ster-van-zwolle/2020
# Extracting 1day race:: race/grand-prix-velo-alanya/2020
# Extracting 1day race:: race/kuurne-brussel-kuurne/2020
# Extracting 1day race:: race/la-drome-classic/2020
# Extracting 1day race:: race/grand-prix-manavgat-side/2020
# Extracting 1day race:: race/grand-prix-manavgat-side-we/2020
# Extracting 1day race:: race/international-rhodes-gp/2020
# Extracting 1day race:: race/gp-samyn/2020
# Extracting 1day race:: race/trofej-umag-umag-trophy/2020
# Extracting stage race: race/tour-of-rhodes/2020/stage-1
# Extracting stage race: race/tour-of-rhodes/2020/stage-2
# Extracting stage race: race/tour-of-rhodes/2020/stage-3
# Extracting 1day race:: race/grote-prijs-jean-pierre-monsere/2020
# Extracting 1day race:: race/dorpenomloop-rucphen/2020
# Extracting 1day race:: race/gp-de-la-ville-de-lillers/2020
# Extracting 1day race:: race/porec-trophy-trofej-porec/2020
# NC race: race/nc-poland-u23-itt/2020
# NC race: race/nc-slovenia/2020
# NC race: race/nc-slovenia-itt/2020
# NC race: race/nc-switzerland-itt/2020
# NC race: race/nc-switzerland-u23-itt/2020
# Extracting stage race: race/dookola-mazowsza/2020/stage-1
# Extracting stage race: race/dookola-mazowsza/2020/stage-2
# Extracting stage race: race/dookola-mazowsza/2020/stage-3
# Extracting stage race: race/dookola-mazowsza/2020/stage-4
# NC race: race/nc-croatia-itt/2020
# NC race: race/nc-croatia-u23-itt/2020
# NC race: race/nc-croatia/2020
# Extracting 1day race:: race/puchar-ministra-obrony-narodowej/2020
# Extraction failed: race/sibiu-cycling-tour/2020
# NC race: race/nc-belarus-itt/2020
# NC race: race/nc-belarus-u23-itt/2020
# NC race: race/nc-norway-itt/2020
# NC race: race/nc-sweden-itt/2020
# Extracting stage race: race/in-the-footsteps-of-the-romans/2020/stage-1
# Extracting stage race: race/in-the-footsteps-of-the-romans/2020/stage-2
# NC race: race/nc-greece-u23-itt/2020
# NC race: race/nc-belarus/2020
# Extracting 1day race:: race/vn-kranja-memorijal-filipa-majcna/2020
# NC race: race/nc-greece-u23/2020
# Extracting stage race: race/vuelta-a-burgos/2020/stage-1
# Extracting stage race: race/vuelta-a-burgos/2020/stage-2
# Extracting stage race: race/vuelta-a-burgos/2020/stage-3
# Extracting stage race: race/vuelta-a-burgos/2020/stage-4
# Extracting stage race: race/vuelta-a-burgos/2020/stage-5
# Extracting stage race: race/tour-of-bulgaria/2020/stage-1
# Extracting stage race: race/tour-of-bulgaria/2020/stage-2
# Extracting stage race: race/tour-of-bulgaria/2020/stage-3
# Extracting stage race: race/tour-of-bulgaria/2020/stage-4
# Extracting stage race: race/la-route-d-occitanie/2020/stage-1
# Extracting stage race: race/la-route-d-occitanie/2020/stage-2
# Extracting stage race: race/la-route-d-occitanie/2020/stage-3
# Extracting stage race: race/la-route-d-occitanie/2020/stage-4
# NC race: race/nc-italy-u23-itt/2020
# Extracting 1day race:: race/circuito-de-getxo/2020
# Extracting 1day race:: race/gran-trittico-lombardo/2020
# Extracting 1day race:: race/milano-torino/2020
# Extraction failed: race/tour-of-szeklerland/2020
# Extracting stage race: race/tour-des-pays-de-savoie/2020/stage-1
# Extracting stage race: race/tour-des-pays-de-savoie/2020/stage-2
# Extracting stage race: race/tour-des-pays-de-savoie/2020/stage-3
# Extracting stage race: race/tour-des-pays-de-savoie/2020/stage-4
# Extracting stage race: race/tour-des-pays-de-savoie/2020/stage-5
# Extracting stage race: race/sazka-tour/2020/stage-1
# Extraction failed: race/sazka-tour/2020
# Extracting 1day race:: race/mont-ventoux-denivele-challenge/2020
# NC race: race/nc-ukraine-itt/2020
# NC race: race/nc-ukraine-u23-itt/2020
# Extracting stage race: race/tour-de-l-ain/2020/stage-1
# Extracting stage race: race/tour-de-l-ain/2020/stage-2
# Extracting stage race: race/tour-de-l-ain/2020/stage-3
# NC race: race/nc-ukraine-u23/2020
# NC race: race/nc-ukraine/2020
# Extracting 1day race:: race/gran-piemonte/2020
# Extracting stage race: race/tour-bitwa-warszawska-1920/2020/stage-1
# Extracting stage race: race/tour-bitwa-warszawska-1920/2020/stage-2
# NC race: race/nc-norway/2020
# NC race: race/nc-poland/2020
# NC race: race/nc-spain/2020
# Extracting 1day race:: race/uec-road-european-championships-itt/2020
# Extraction failed: race/european-continental-championships-u23-itt/2020
# Extracting 1day race:: race/uec-road-european-championships/2020
# Extracting stage race: race/tour-du-poitou-charentes-et-de-la-vienne/2020/stage-1
# Extracting stage race: race/tour-du-poitou-charentes-et-de-la-vienne/2020/stage-2
# Extracting stage race: race/tour-du-poitou-charentes-et-de-la-vienne/2020/stage-3
# Extraction failed: race/tour-du-poitou-charentes-et-de-la-vienne/2020
# Extracting 1day race:: race/european-championships/2020
# Extraction failed: race/european-continental-championships-mixed-relay-ttt/2020
# Extracting 1day race:: race/druivenkoers-overijse/2020
# Extracting stage race: race/tour-de-hongrie/2020/stage-1
# Extracting stage race: race/tour-de-hongrie/2020/stage-2
# Extracting stage race: race/tour-de-hongrie/2020/stage-3
# Extracting stage race: race/tour-de-hongrie/2020/stage-4
# Extracting stage race: race/tour-de-hongrie/2020/stage-5
# Extracting 1day race:: race/trofeo-matteotti/2020
# Extracting stage race: race/giro-ciclistico-d-italia/2020/stage-1
# Extracting stage race: race/giro-ciclistico-d-italia/2020/stage-2
# Extracting stage race: race/giro-ciclistico-d-italia/2020/stage-3
# Extracting stage race: race/giro-ciclistico-d-italia/2020/stage-4
# Extracting stage race: race/giro-ciclistico-d-italia/2020/stage-5
# Extracting stage race: race/giro-ciclistico-d-italia/2020/stage-6
# Extracting stage race: race/giro-ciclistico-d-italia/2020/stage-7
# Extracting stage race: race/giro-ciclistico-d-italia/2020/stage-8
# NC race: race/national-championships-kosovo-u23-road-race/2020
# Extracting 1day race:: race/brussels-cycling-classic/2020
# Extracting 1day race:: race/memorial-marco-pantani/2020
# Extracting 1day race:: race/carpathia-couriers-paths/2020
# Extracting stage race: race/settimana-internazionale-coppi-e-bartali/2020/stage-1
# Extraction failed: race/settimana-internazionale-coppi-e-bartali/2020
# Extracting stage race: race/tour-de-serbie/2020/stage-1
# Extracting stage race: race/tour-de-serbie/2020/stage-2
# Extracting stage race: race/tour-de-serbie/2020/stage-3
# Extracting stage race: race/baltyk-karkonosze-tour/2020/stage-1
# Extracting stage race: race/baltyk-karkonosze-tour/2020/stage-2
# Extracting stage race: race/baltyk-karkonosze-tour/2020/stage-3
# Extracting stage race: race/baltyk-karkonosze-tour/2020/stage-4
# Extraction failed: race/baltyk-karkonosze-tour/2020
# Extracting 1day race:: race/grand-prix-develi/2020
# Extracting stage race: race/banja-luka-belgrade-i/2020/stage-1
# Extracting stage race: race/banja-luka-belgrade-i/2020/stage-2
# Extracting stage race: race/banja-luka-belgrade-i/2020/stage-3
# Extracting stage race: race/banja-luka-belgrade-i/2020/stage-4
# NC race: race/nc-greece-itt/2020
# Extracting 1day race:: race/grand-prix-cappadocia/2020
# Extracting 1day race:: race/hafjell-gp/2020
# NC race: race/nc-kosovo-itt/2020
# Extracting 1day race:: race/grand-prix-mount-erciyes-2200-mt/2020
# Extracting 1day race:: race/lillehammer-gp/2020
# NC race: race/national-championships-kosovo-u23-itt/2020
# NC race: race/nc-greece/2020
# NC race: race/nc-kosovo/2020
# NC race: race/nc-latvia/2020
# Extracting 1day race:: race/tour-du-doubs/2020
# Extracting 1day race:: race/grand-prix-world-s-best-high-altitude/2020
# Extraction failed: race/gylne-gutuer/2020
# NC race: race/nc-germany-u23-itt/2020
# Extracting stage race: race/romanian-cycling-tour/2020/stage-1
# Extracting stage race: race/romanian-cycling-tour/2020/stage-2
# Extracting stage race: race/romanian-cycling-tour/2020/stage-3
# Extracting stage race: race/romanian-cycling-tour/2020/stage-4
# Extracting stage race: race/romanian-cycling-tour/2020/stage-5
# Extracting stage race: race/course-cycliste-de-solidarnosc/2020/stage-1
# Extracting stage race: race/course-cycliste-de-solidarnosc/2020/stage-2
# Extracting stage race: race/course-cycliste-de-solidarnosc/2020/stage-3
# Extraction failed: race/course-cycliste-de-solidarnosc/2020
# NC race: race/nc-denmark-u23-itt/2020
# NC race: race/nc-latvia-itt/2020
# NC race: race/nc-serbia/2020
# NC race: race/nc-latvia-u23-itt/2020
# NC race: race/nc-norway-u23/2020
# Extracting stage race: race/orlen-nations-grand-prix/2020/stage-1
# Extraction failed: race/orlen-nations-grand-prix/2020
# NC race: race/nc-italy-u23/2020
# Extracting 1day race:: race/antwerp-port-epic/2020
# NC race: race/nc-denmark-u23/2020
# Extracting 1day race:: race/grand-prix-velo-erciyes-me/2020
# Extracting stage race: race/tour-de-luxembourg/2020/stage-1
# Extraction failed: race/tour-de-luxembourg/2020
# Extracting 1day race:: race/grand-prix-central-anatolia/2020
# Extracting 1day race:: race/giro-di-toscana/2020
# Extracting stage race: race/okolo-slovenska/2020/stage-1
# Extraction failed: race/okolo-slovenska/2020
# Extracting 1day race:: race/gp-citta-di-peccioli/2020
# Extracting stage race: race/ronde-de-l-isard/2020/stage-1
# Extracting stage race: race/ronde-de-l-isard/2020/stage-2
# Extraction failed: race/ronde-de-l-isard/2020
# Extracting stage race: race/tour-of-malopolska/2020/stage-1
# Extracting stage race: race/tour-of-malopolska/2020/stage-2
# Extracting stage race: race/tour-of-malopolska/2020/stage-3
# NC race: race/nc-moldova-itt/2020
# Extracting 1day race:: race/giro-del-appennino/2020
# NC race: race/nc-moldova/2020
# Extracting stage race: race/gp-int-torres-vedras/2020/stage-1
# Extracting stage race: race/gp-int-torres-vedras/2020/stage-2
# Extracting 1day race:: race/gooikse-pijl/2020
# Extracting 1day race:: race/gp-d-isbergues/2020
# Extracting 1day race:: race/gp-industria-e-commercio2/2020
# NC race: race/nc-belgium/2020
# NC race: race/nc-turkey-itt/2020
# NC race: race/national-championships-turkey-u23-itt/2020
# Extracting 1day race:: race/paris-camembert/2020
# NC race: race/nc-turkey/2020
# Extracting 1day race:: race/world-championship-we/2020
# Extracting stage race: race/tour-of-mevlana/2020/stage-1
# Extracting stage race: race/tour-of-mevlana/2020/stage-2
# Extracting 1day race:: race/world-championship/2020
# Extracting 1day race:: race/paris-chauny-classique/2020
# Extracting stage race: race/volta-a-portugal/2020/stage-1
# Extracting stage race: race/volta-a-portugal/2020/stage-2
# Extracting stage race: race/volta-a-portugal/2020/stage-3
# Extracting stage race: race/volta-a-portugal/2020/stage-4
# Extracting stage race: race/volta-a-portugal/2020/stage-5
# Extracting stage race: race/volta-a-portugal/2020/stage-6
# Extracting stage race: race/volta-a-portugal/2020/stage-7
# Extracting stage race: race/volta-a-portugal/2020/stage-8
# NC race: race/nc-ireland-itt/2020
# NC race: race/nc-ireland-itt-u23/2020
# NC race: race/nc-denmark-itt/2020
# NC race: race/nc-ireland/2020
# NC race: race/nc-sweden/2020
# Extracting 1day race:: race/piccolo-giro-di-lombardia/2020
# Extracting 1day race:: race/brabantse-pijl/2020
# Extracting stage race: race/giro-della-regione-friuli-venezia-giulia/2020/stage-1
# Extraction failed: race/giro-della-regione-friuli-venezia-giulia/2020
# Extracting 1day race:: race/visegrad-4-bicycle-race-gp-slovakia/2020
# Extracting 1day race:: race/paris-tours/2020
# Extracting 1day race:: race/paris-tours-espoirs/2020
# Extracting 1day race:: race/prueba-villafranca/2020
# Extraction failed: race/scheldeprijs/2020
# NC race: race/nc-cyprus-itt/2020
# NC race: race/nc-belgium-u23/2020
# NC race: race/nc-cyprus/2020
# NC race: race/nc-france-itt-u23/2020
# NC race: race/nc-france-u23/2020
# NC race: race/nc-switserland/2020
# NC race: race/nc-israel-itt/2020
# NC race: race/national-championships-u23-itt/2020
# Extracting stage race: race/uae-tour/2021/stage-1
# Extracting stage race: race/uae-tour/2021/stage-2
# Extracting stage race: race/uae-tour/2021/stage-3
# Extracting stage race: race/uae-tour/2021/stage-4
# Extracting stage race: race/uae-tour/2021/stage-5
# Extracting stage race: race/uae-tour/2021/stage-6
# Extracting stage race: race/uae-tour/2021/stage-7
# Extracting 1day race:: race/omloop-het-nieuwsblad/2021
# Extracting 1day race:: race/strade-bianche/2021
# Extracting stage race: race/paris-nice/2021/stage-1
# Extracting stage race: race/paris-nice/2021/stage-2
# Extracting stage race: race/paris-nice/2021/stage-3
# Extracting stage race: race/paris-nice/2021/stage-4
# Extracting stage race: race/paris-nice/2021/stage-5
# Extracting stage race: race/paris-nice/2021/stage-6
# Extracting stage race: race/paris-nice/2021/stage-7
# Extracting stage race: race/paris-nice/2021/stage-8
# Extracting stage race: race/tirreno-adriatico/2021/stage-1
# Extracting stage race: race/tirreno-adriatico/2021/stage-2
# Extracting stage race: race/tirreno-adriatico/2021/stage-3
# Extracting stage race: race/tirreno-adriatico/2021/stage-4
# Extracting stage race: race/tirreno-adriatico/2021/stage-5
# Extracting stage race: race/tirreno-adriatico/2021/stage-6
# Extracting stage race: race/tirreno-adriatico/2021/stage-7
# Extracting 1day race:: race/milano-sanremo/2021
# Extracting stage race: race/volta-a-catalunya/2021/stage-1
# Extracting stage race: race/volta-a-catalunya/2021/stage-2
# Extracting stage race: race/volta-a-catalunya/2021/stage-3
# Extracting stage race: race/volta-a-catalunya/2021/stage-4
# Extracting stage race: race/volta-a-catalunya/2021/stage-5
# Extracting stage race: race/volta-a-catalunya/2021/stage-6
# Extracting stage race: race/volta-a-catalunya/2021/stage-7
# Extracting 1day race:: race/oxyclean-classic-brugge-de-panne/2021
# Extracting 1day race:: race/e3-harelbeke/2021
# Extracting 1day race:: race/gent-wevelgem/2021
# Extracting 1day race:: race/dwars-door-vlaanderen/2021
# Extracting 1day race:: race/ronde-van-vlaanderen/2021
# Extracting stage race: race/itzulia-basque-country/2021/stage-1
# Extracting stage race: race/itzulia-basque-country/2021/stage-2
# Extracting stage race: race/itzulia-basque-country/2021/stage-3
# Extracting stage race: race/itzulia-basque-country/2021/stage-4
# Extracting stage race: race/itzulia-basque-country/2021/stage-5
# Extracting stage race: race/itzulia-basque-country/2021/stage-6
# Extracting 1day race:: race/amstel-gold-race/2021
# Extracting 1day race:: race/la-fleche-wallone/2021
# Extracting 1day race:: race/liege-bastogne-liege/2021
# Extracting stage race: race/tour-de-romandie/2021/stage-1
# Extracting stage race: race/tour-de-romandie/2021/stage-2
# Extracting stage race: race/tour-de-romandie/2021/stage-3
# Extracting stage race: race/tour-de-romandie/2021/stage-4
# Extracting stage race: race/tour-de-romandie/2021/stage-5
# Extracting stage race: race/giro-d-italia/2021/stage-1
# Extracting stage race: race/giro-d-italia/2021/stage-2
# Extracting stage race: race/giro-d-italia/2021/stage-3
# Extracting stage race: race/giro-d-italia/2021/stage-4
# Extracting stage race: race/giro-d-italia/2021/stage-5
# Extracting stage race: race/giro-d-italia/2021/stage-6
# Extracting stage race: race/giro-d-italia/2021/stage-7
# Extracting stage race: race/giro-d-italia/2021/stage-8
# Extracting stage race: race/giro-d-italia/2021/stage-9
# Extracting stage race: race/giro-d-italia/2021/stage-10
# Extracting stage race: race/giro-d-italia/2021/stage-11
# Extracting stage race: race/giro-d-italia/2021/stage-12
# Extracting stage race: race/giro-d-italia/2021/stage-13
# Extracting stage race: race/giro-d-italia/2021/stage-14
# Extracting stage race: race/giro-d-italia/2021/stage-15
# Extracting stage race: race/giro-d-italia/2021/stage-16
# Extracting stage race: race/giro-d-italia/2021/stage-17
# Extracting stage race: race/giro-d-italia/2021/stage-18
# Extracting stage race: race/giro-d-italia/2021/stage-19
# Extracting stage race: race/giro-d-italia/2021/stage-20
# Extracting stage race: race/giro-d-italia/2021/stage-21
# Extracting stage race: race/dauphine/2021/stage-1
# Extracting stage race: race/dauphine/2021/stage-2
# Extracting stage race: race/dauphine/2021/stage-3
# Extracting stage race: race/dauphine/2021/stage-4
# Extracting stage race: race/dauphine/2021/stage-5
# Extracting stage race: race/dauphine/2021/stage-6
# Extracting stage race: race/dauphine/2021/stage-7
# Extracting stage race: race/dauphine/2021/stage-8
# Extracting stage race: race/tour-de-suisse/2021/stage-1
# Extracting stage race: race/tour-de-suisse/2021/stage-2
# Extracting stage race: race/tour-de-suisse/2021/stage-3
# Extracting stage race: race/tour-de-suisse/2021/stage-4
# Extracting stage race: race/tour-de-suisse/2021/stage-5
# Extracting stage race: race/tour-de-suisse/2021/stage-6
# Extracting stage race: race/tour-de-suisse/2021/stage-7
# Extracting stage race: race/tour-de-suisse/2021/stage-8
# Extracting stage race: race/tour-de-france/2021/stage-1
# Extracting stage race: race/tour-de-france/2021/stage-2
# Extracting stage race: race/tour-de-france/2021/stage-3
# Extracting stage race: race/tour-de-france/2021/stage-4
# Extracting stage race: race/tour-de-france/2021/stage-5
# Extracting stage race: race/tour-de-france/2021/stage-6
# Extracting stage race: race/tour-de-france/2021/stage-7
# Extracting stage race: race/tour-de-france/2021/stage-8
# Extracting stage race: race/tour-de-france/2021/stage-9
# Extracting stage race: race/tour-de-france/2021/stage-10
# Extracting stage race: race/tour-de-france/2021/stage-11
# Extracting stage race: race/tour-de-france/2021/stage-12
# Extracting stage race: race/tour-de-france/2021/stage-13
# Extracting stage race: race/tour-de-france/2021/stage-14
# Extracting stage race: race/tour-de-france/2021/stage-15
# Extracting stage race: race/tour-de-france/2021/stage-16
# Extracting stage race: race/tour-de-france/2021/stage-17
# Extracting stage race: race/tour-de-france/2021/stage-18
# Extracting stage race: race/tour-de-france/2021/stage-19
# Extracting stage race: race/tour-de-france/2021/stage-20
# Extracting stage race: race/tour-de-france/2021/stage-21
# Extracting 1day race:: race/san-sebastian/2021
# Extracting stage race: race/tour-de-pologne/2021/stage-1
# Extracting stage race: race/tour-de-pologne/2021/stage-2
# Extracting stage race: race/tour-de-pologne/2021/stage-3
# Extracting stage race: race/tour-de-pologne/2021/stage-4
# Extracting stage race: race/tour-de-pologne/2021/stage-5
# Extracting stage race: race/tour-de-pologne/2021/stage-6
# Extracting stage race: race/tour-de-pologne/2021/stage-7
# Extracting stage race: race/vuelta-a-espana/2021/stage-1
# Extracting stage race: race/vuelta-a-espana/2021/stage-2
# Extracting stage race: race/vuelta-a-espana/2021/stage-3
# Extracting stage race: race/vuelta-a-espana/2021/stage-4
# Extracting stage race: race/vuelta-a-espana/2021/stage-5
# Extracting stage race: race/vuelta-a-espana/2021/stage-6
# Extracting stage race: race/vuelta-a-espana/2021/stage-7
# Extracting stage race: race/vuelta-a-espana/2021/stage-8
# Extracting stage race: race/vuelta-a-espana/2021/stage-9
# Extracting stage race: race/vuelta-a-espana/2021/stage-10
# Extracting stage race: race/vuelta-a-espana/2021/stage-11
# Extracting stage race: race/vuelta-a-espana/2021/stage-12
# Extracting stage race: race/vuelta-a-espana/2021/stage-13
# Extracting stage race: race/vuelta-a-espana/2021/stage-14
# Extracting stage race: race/vuelta-a-espana/2021/stage-15
# Extracting stage race: race/vuelta-a-espana/2021/stage-16
# Extracting stage race: race/vuelta-a-espana/2021/stage-17
# Extracting stage race: race/vuelta-a-espana/2021/stage-18
# Extracting stage race: race/vuelta-a-espana/2021/stage-19
# Extracting stage race: race/vuelta-a-espana/2021/stage-20
# Extracting stage race: race/vuelta-a-espana/2021/stage-21
# Extracting 1day race:: race/bretagne-classic/2021
# Extracting stage race: race/benelux-tour/2021/stage-1
# Extracting stage race: race/benelux-tour/2021/stage-2
# Extracting stage race: race/benelux-tour/2021/stage-3
# Extracting stage race: race/benelux-tour/2021/stage-4
# Extracting stage race: race/benelux-tour/2021/stage-5
# Extracting stage race: race/benelux-tour/2021/stage-6
# Extracting stage race: race/benelux-tour/2021/stage-7
# Extracting 1day race:: race/Eschborn-Frankfurt/2021
# Extracting 1day race:: race/paris-roubaix/2021
# Extracting 1day race:: race/il-lombardia/2021
# Extracting 1day race:: race/gp-de-valence/2021
# Extracting 1day race:: race/gp-d-ouverture/2021
# Extracting stage race: race/etoile-de-besseges/2021/stage-1
# Extracting stage race: race/etoile-de-besseges/2021/stage-2
# Extracting stage race: race/etoile-de-besseges/2021/stage-3
# Extracting stage race: race/etoile-de-besseges/2021/stage-4
# Extracting stage race: race/etoile-de-besseges/2021/stage-5
# Extracting 1day race:: race/grand-prix-alanya/2021
# Extracting 1day race:: race/grand-prix-gazipasa/2021
# Extracting stage race: race/tour-des-alpes-maritimes-et-du-var/2021/stage-1
# Extracting stage race: race/tour-des-alpes-maritimes-et-du-var/2021/stage-2
# Extracting stage race: race/tour-des-alpes-maritimes-et-du-var/2021/stage-3
# Extracting 1day race:: race/grand-prix-manavgat-side/2021
# Extracting 1day race:: race/grand-prix-velo-alanya/2021
# Extracting 1day race:: race/gp-samyn/2021
# Extracting 1day race:: race/trofej-umag-umag-trophy/2021
# Extracting 1day race:: race/grand-prix-mediterrennean/2021
# Extracting 1day race:: race/grote-prijs-jean-pierre-monsere/2021
# Extracting 1day race:: race/grand-prix-gundogmus-me/2021
# Extracting 1day race:: race/porec-trophy-trofej-porec/2021
# Extracting stage race: race/istarsko-proljece-istrian-spring-trophy/2021/stage-1
# Extracting stage race: race/istarsko-proljece-istrian-spring-trophy/2021/stage-2
# Extracting stage race: race/istarsko-proljece-istrian-spring-trophy/2021/stage-3
# Extracting stage race: race/istarsko-proljece-istrian-spring-trophy/2021/stage-4
# Extracting 1day race:: race/paris-troyes/2021
# Extracting 1day race:: race/per-sempre-alfredo/2021
# Extracting 1day race:: race/gp-izola-butan-plin/2021
# Extracting stage race: race/settimana-internazionale-coppi-e-bartali/2021/stage-1
# Extraction failed: race/settimana-internazionale-coppi-e-bartali/2021
# Extracting 1day race:: race/cholet-pays-de-loire/2021
# Extracting 1day race:: race/gp-adria-mobil/2021
# Extracting stage race: race/tour-of-mevlana/2021/stage-1
# Extracting stage race: race/tour-of-mevlana/2021/stage-2
# Extracting stage race: race/tour-of-mevlana/2021/stage-3
# Extracting stage race: race/tour-of-mevlana/2021/stage-4
# Extracting 1day race:: race/la-roue-tourangelle/2021
# Extracting 1day race:: race/international-rhodes-gp/2021
# Extracting 1day race:: race/trofeo-piva/2021
# Extracting 1day race:: race/circuito-belvedere/2021
# Extracting stage race: race/tour-of-rhodes/2021/stage-1
# Extraction failed: race/tour-of-rhodes/2021
# Extracting 1day race:: race/gp-industria-e-commercio2/2021
# Extracting stage race: race/banja-luka-belgrade-i/2021/stage-1
# Extracting stage race: race/banja-luka-belgrade-i/2021/stage-2
# Extracting stage race: race/banja-luka-belgrade-i/2021/stage-3
# Extracting stage race: race/banja-luka-belgrade-i/2021/stage-4
# Extracting 1day race:: race/gran-premio-della-liberazione/2021
# Extracting stage race: race/vuelta-asturias/2021/stage-1
# Extracting stage race: race/vuelta-asturias/2021/stage-2
# Extracting stage race: race/vuelta-asturias/2021/stage-3
# Extracting 1day race:: race/circuito-del-porto-trofeo-arvedi/2021
# Extracting 1day race:: race/classica-da-arrabida-cylin-portugal/2021
# Extracting stage race: race/tour-de-hongrie/2021/stage-1
# Extracting stage race: race/tour-de-hongrie/2021/stage-2
# Extracting stage race: race/tour-de-hongrie/2021/stage-3
# Extracting stage race: race/tour-de-hongrie/2021/stage-4
# Extracting stage race: race/tour-de-hongrie/2021/stage-5
# Extracting 1day race:: race/circuit-de-wallonie/2021
# Extracting 1day race:: race/trofeo-calvia/2021
# Extracting 1day race:: race/deia-trophy/2021
# Extracting stage race: race/tour-d-eure-et-loir/2021/stage-1
# Extracting stage race: race/tour-d-eure-et-loir/2021/stage-2
# Extracting stage race: race/tour-d-eure-et-loir/2021/stage-3
# Extracting 1day race:: race/trofeo-andratx-mirador-d-es-colomer/2021
# Extraction failed: race/trofeo-alcudia/2021
# Extracting stage race: race/rhone-alpes-isere-tour/2021/stage-1
# Extracting stage race: race/rhone-alpes-isere-tour/2021/stage-2
# Extracting stage race: race/rhone-alpes-isere-tour/2021/stage-3
# Extracting stage race: race/rhone-alpes-isere-tour/2021/stage-4
# Extracting stage race: race/rhone-alpes-isere-tour/2021/stage-5
# Extracting 1day race:: race/tour-du-finistere/2021
# Extracting 1day race:: race/vuelta-ciclista-a-la-region-de-murcia/2021
# Extracting 1day race:: race/mercan-tour-classic-alpes-maritimes/2021
# Extracting 1day race:: race/ronde-van-limburg/2021
# NC race: race/nc-germany-u23/2021
# NC race: race/nc-luxembourg-u23/2021
# NC race: race/nc-suisse-u23/2021
# Extracting stage race: race/tour-de-la-mirabelle/2021/stage-1
# Extracting stage race: race/tour-de-la-mirabelle/2021/stage-2
# Extracting stage race: race/tour-de-la-mirabelle/2021/stage-3
# Extracting stage race: race/tour-of-estonia/2021/stage-1
# Extracting stage race: race/tour-of-estonia/2021/stage-2
# Extracting 1day race:: race/gp-herning/2021
# Extracting 1day race:: race/coppa-della-pace-trofeo-flli-anelli/2021
# Extraction failed: race/albani-classic-fyen-rundt/2021
# Extracting 1day race:: race/gp-slovenia/2021
# Extracting 1day race:: race/trofeo-alcide-degasperi/2021
# Extracting stage race: race/giro-ciclistico-d-italia/2021/stage-1
# Extracting stage race: race/giro-ciclistico-d-italia/2021/stage-2
# Extracting stage race: race/giro-ciclistico-d-italia/2021/stage-3
# Extracting stage race: race/giro-ciclistico-d-italia/2021/stage-4
# Extracting stage race: race/giro-ciclistico-d-italia/2021/stage-5
# Extracting stage race: race/giro-ciclistico-d-italia/2021/stage-6
# Extracting stage race: race/giro-ciclistico-d-italia/2021/stage-7
# Extracting stage race: race/giro-ciclistico-d-italia/2021/stage-8
# Extracting stage race: race/giro-ciclistico-d-italia/2021/stage-9
# Extracting stage race: race/giro-ciclistico-d-italia/2021/stage-10
# Extracting stage race: race/tour-of-malopolska/2021/stage-1
# Extracting stage race: race/tour-of-malopolska/2021/stage-2
# Extracting stage race: race/tour-of-malopolska/2021/stage-3
# Extracting 1day race:: race/gp-du-canton-d-argovie/2021
# NC race: race/nc-greece-u23-itt/2021
# Extracting 1day race:: race/circuit-des-xi-villes/2021
# NC race: race/nc-greece-u23/2021
# Extracting 1day race:: race/mont-ventoux-denivele-challenge/2021
# Extracting stage race: race/five-rings-of-moscow/2021/stage-1
# Extracting stage race: race/five-rings-of-moscow/2021/stage-2
# Extracting stage race: race/five-rings-of-moscow/2021/stage-3
# Extracting stage race: race/five-rings-of-moscow/2021/stage-4
# Extracting stage race: race/la-route-d-occitanie/2021/stage-1
# Extracting stage race: race/la-route-d-occitanie/2021/stage-2
# Extracting stage race: race/la-route-d-occitanie/2021/stage-3
# Extracting stage race: race/la-route-d-occitanie/2021/stage-4
# Extracting stage race: race/oberosterreichrundfahrt/2021/stage-1
# Extraction failed: race/oberosterreichrundfahrt/2021
# NC race: race/national-championships-estonia-mu23-road-race/2021
# NC race: race/nc-latvia-u23/2021
# NC race: race/nc-lithuania-u23/2021
# NC race: race/nc-norway-u23/2021
# Extracting stage race: race/adriatica-ionica-race/2021/stage-1
# Extracting stage race: race/adriatica-ionica-race/2021/stage-2
# Extracting stage race: race/adriatica-ionica-race/2021/stage-3
# Extracting stage race: race/giro-ciclistico-della-valle-d-aosta-mont-blanc/2021/stage-1
# Extraction failed: race/giro-ciclistico-della-valle-d-aosta-mont-blanc/2021
# Extracting stage race: race/gp-int-torres-vedras/2021/stage-1
# Extracting stage race: race/gp-int-torres-vedras/2021/stage-2
# Extracting stage race: race/gp-int-torres-vedras/2021/stage-3
# Extracting stage race: race/tour-of-kosovo/2021/stage-1
# Extracting stage race: race/tour-of-kosovo/2021/stage-2
# Extracting stage race: race/tour-of-kosovo/2021/stage-3
# Extraction failed: race/grand-prix-velo-erciyes-me/2021
# Extracting 1day race:: race/gp-czech-republic/2021
# Extraction failed: race/grand-prix-develi/2021
# Extracting 1day race:: race/gp-de-la-ville-de-nogent-sur-oise/2021
# Extracting 1day race:: race/puchar-ministra-obrony-narodowej/2021
# Extracting 1day race:: race/visegrad-4-bicycle-race-gp-polski-via-odra/2021
# Extracting stage race: race/tour-alsace/2021/stage-1
# Extraction failed: race/tour-alsace/2021
# Extracting 1day race:: race/prueba-villafranca/2021
# Extracting 1day race:: race/vn-kranja-memorijal-filipa-majcna/2021
# Extracting 1day race:: race/grand-prix-de-la-ville-de-perenchies/2021
# NC race: race/nc-france-itt-u23/2021
# Extracting stage race: race/tour-de-l-ain/2021/stage-1
# Extracting stage race: race/tour-de-l-ain/2021/stage-2
# Extracting stage race: race/tour-de-l-ain/2021/stage-3
# Extracting 1day race:: race/vuelta-a-castilla-y-leon/2021
# NC race: race/nc-france-u23/2021
# Extracting stage race: race/kreiz-breizh-elites/2021/stage-1
# Extraction failed: race/kreiz-breizh-elites/2021
# Extracting 1day race:: race/heist-op-den-berg/2021
# Extracting 1day race:: race/circuito-de-getxo/2021
# Extracting stage race: race/volta-a-portugal/2021/stage-1
# Extracting stage race: race/volta-a-portugal/2021/stage-2
# Extracting stage race: race/volta-a-portugal/2021/stage-3
# Extracting stage race: race/volta-a-portugal/2021/stage-4
# Extracting stage race: race/volta-a-portugal/2021/stage-5
# Extracting stage race: race/volta-a-portugal/2021/stage-6
# Extracting stage race: race/volta-a-portugal/2021/stage-7
# Extracting stage race: race/volta-a-portugal/2021/stage-8
# ...
# Extracting stage race: race/banja-luka-belgrade-i/2022/stage-1
# Extraction failed: race/banja-luka-belgrade-i/2022
# Extracting stage race: race/tour-du-loir-et-cher-e.-provost-/2022/stage-1
# Extracting stage race: race/tour-du-loir-et-cher-e.-provost-/2022/stage-2
# Extracting stage race: race/tour-du-loir-et-cher-e.-provost-/2022/stage-3
# Extracting stage race: race/tour-du-loir-et-cher-e.-provost-/2022/stage-4
# Extracting stage race: race/tour-du-loir-et-cher-e.-provost-/2022/stage-5
# Extracting 1day race:: race/classic-grand-besancon-doubs/2022
# NC race: race/nc-greece-u23-itt/2022
# Extracting 1day race:: race/tour-du-jura-cycliste/2022
# Extracting 1day race:: race/arno-wallaard-memorial/2022
# Extracting 1day race:: race/liege-bastogne-liege-u23/2022
# NC race: race/nc-greece-u23/2022
# Extraction failed: race/circuito-belvedere/2022
# Extracting 1day race:: race/gp-palio-del-recioto/2022
# Extracting 1day race:: race/east-midlands-international-cicle-classic/2022
# Extracting 1day race:: race/gran-premio-della-liberazione/2022
# Extracting stage race: race/le-tour-de-bretagne/2022/stage-1
# Extracting stage race: race/le-tour-de-bretagne/2022/stage-2
# Extracting stage race: race/le-tour-de-bretagne/2022/stage-3
# Extracting stage race: race/le-tour-de-bretagne/2022/stage-4
# Extracting stage race: race/le-tour-de-bretagne/2022/stage-5
# Extracting stage race: race/le-tour-de-bretagne/2022/stage-6
# Extracting stage race: race/le-tour-de-bretagne/2022/stage-7
# Extracting stage race: race/international-tour-of-hellas/2022/stage-1
# Extracting stage race: race/international-tour-of-hellas/2022/stage-2
# Extracting stage race: race/international-tour-of-hellas/2022/stage-3
# Extracting stage race: race/international-tour-of-hellas/2022/stage-4
# Extracting stage race: race/international-tour-of-hellas/2022/stage-5
# Extracting stage race: race/vuelta-asturias/2022/stage-1
# Extracting stage race: race/vuelta-asturias/2022/stage-2
# Extracting stage race: race/vuelta-asturias/2022/stage-3
# Extracting stage race: race/carpathia-couriers-paths/2022/stage-1
# Extracting stage race: race/carpathia-couriers-paths/2022/stage-2
# Extracting stage race: race/carpathia-couriers-paths/2022/stage-3
# Extracting stage race: race/carpathia-couriers-paths/2022/stage-4
# Extracting stage race: race/carpathia-couriers-paths/2022/stage-5
# Extracting 1day race:: race/grand-prix-nasielsk-serock/2022
# Extracting 1day race:: race/grand-prix-wyszkow/2022
# Extracting 1day race:: race/zodc-zuidenveld-tour/2022
# Extracting 1day race:: race/circuito-del-porto-trofeo-arvedi/2022
# NC race: race/nc-belgium-u23-itt/2022
# NC race: race/nc-cyprus-itt/2022
# Extracting 1day race:: race/ronde-van-overijssel2/2022
# Extracting 1day race:: race/hadeland-gp/2022
# NC race: race/nc-cyprus/2022
# Extracting 1day race:: race/fleche-ardennaise/2022
# Extracting 1day race:: race/gp-industrie-del-marmo/2022
# Extracting 1day race:: race/ringerike-gp/2022
# Extracting stage race: race/tour-de-hongrie/2022/stage-1
# Extracting stage race: race/tour-de-hongrie/2022/stage-2
# Extracting stage race: race/tour-de-hongrie/2022/stage-3
# Extracting stage race: race/tour-de-hongrie/2022/stage-4
# Extracting stage race: race/tour-de-hongrie/2022/stage-5
# Extracting 1day race:: race/tour-du-finistere/2022
# Extracting 1day race:: race/veenendaal-veenendaal/2022
# Extraction failed: race/gp-herning/2022
# Extracting 1day race:: race/antwerp-port-epic/2022
# Extracting 1day race:: race/boucles-de-l-aulne/2022
# Extracting 1day race:: race/rund-um-koln/2022
# Extracting 1day race:: race/albani-classic-fyen-rundt/2022
# Extraction failed: race/gp-gorenjska/2022
# Extracting stage race: race/rhone-alpes-isere-tour/2022/stage-1
# Extracting stage race: race/rhone-alpes-isere-tour/2022/stage-2
# Extracting stage race: race/rhone-alpes-isere-tour/2022/stage-3
# Extracting stage race: race/rhone-alpes-isere-tour/2022/stage-4
# Extracting stage race: race/rhone-alpes-isere-tour/2022/stage-5
# Extracting stage race: race/fleche-du-sud/2022/stage-1
# Extracting stage race: race/fleche-du-sud/2022/stage-2
# Extracting stage race: race/fleche-du-sud/2022/stage-3
# Extracting stage race: race/fleche-du-sud/2022/stage-4
# Extracting stage race: race/fleche-du-sud/2022/stage-5
# Extracting 1day race:: race/circuit-de-wallonie/2022
# Extracting stage race: race/tour-of-estonia/2022/stage-1
# Extracting stage race: race/tour-of-estonia/2022/stage-2
# Extracting stage race: race/tour-de-la-mirabelle/2022/stage-1
# Extracting stage race: race/tour-de-la-mirabelle/2022/stage-2
# Extracting stage race: race/tour-de-la-mirabelle/2022/stage-3
# Extracting stage race: race/tour-de-la-mirabelle/2022/stage-4
# NC race: race/nc-serbia-u23-itt/2022
# Extracting 1day race:: race/strade-bianche-di-romagna/2022
# Extracting 1day race:: race/grote-prijs-marcel-kint/2022
# NC race: race/national-championships-serbia-road-race-u23/2022
# Extracting 1day race:: race/coppa-della-pace-trofeo-flli-anelli/2022
# Extracting 1day race:: race/mercan-tour-classic-alpes-maritimes/2022
# Extracting stage race: race/tour-of-albania/2022/stage-1
# Extracting stage race: race/tour-of-albania/2022/stage-2
# Extracting stage race: race/tour-of-albania/2022/stage-3
# Extracting stage race: race/tour-of-albania/2022/stage-4
# Extracting stage race: race/tour-of-albania/2022/stage-5
# Extracting 1day race:: race/giro-del-appennino/2022
# Extracting stage race: race/ronde-de-l-oise/2022/stage-1
# Extraction failed: race/ronde-de-l-oise/2022
# Extracting 1day race:: race/trofeo-alcide-degasperi/2022
# Extracting stage race: race/tour-of-malopolska/2022/stage-1
# Extracting stage race: race/tour-of-malopolska/2022/stage-2
# Extraction failed: race/tour-of-malopolska/2022
# Extracting stage race: race/adriatica-ionica-race/2022/stage-1
# Extracting stage race: race/adriatica-ionica-race/2022/stage-2
# Extracting stage race: race/adriatica-ionica-race/2022/stage-3
# Extracting stage race: race/adriatica-ionica-race/2022/stage-4
# Extracting stage race: race/adriatica-ionica-race/2022/stage-5
# Extracting 1day race:: race/heist-op-den-berg/2022
# Extraction failed: race/memorial-philippe-van-coningsloo/2022
# Extracting 1day race:: race/trofeo-citta-di-meldola-g.p.-awc-event/2022
# Extracting 1day race:: race/ronde-van-limburg/2022
# Extraction failed: race/paris-troyes/2022
# Extracting 1day race:: race/coppa-zappi-trofeo-hotel-antico-borgo/2022
# Extracting stage race: race/oberosterreichrundfahrt/2022/stage-1
# Extracting stage race: race/oberosterreichrundfahrt/2022/stage-2
# Extracting stage race: race/oberosterreichrundfahrt/2022/stage-3
# Extracting stage race: race/oberosterreichrundfahrt/2022/stage-4
# Extracting 1day race:: race/gp-du-canton-d-argovie/2022
# Extracting stage race: race/tour-d-eure-et-loir/2022/stage-1
# Extracting stage race: race/tour-d-eure-et-loir/2022/stage-2
# Extracting stage race: race/tour-d-eure-et-loir/2022/stage-3
# Extracting stage race: race/giro-ciclistico-d-italia/2022/stage-1
# Extracting stage race: race/giro-ciclistico-d-italia/2022/stage-2
# Extracting stage race: race/giro-ciclistico-d-italia/2022/stage-3
# Extracting stage race: race/giro-ciclistico-d-italia/2022/stage-4
# Extracting stage race: race/giro-ciclistico-d-italia/2022/stage-5
# Extracting stage race: race/giro-ciclistico-d-italia/2022/stage-6
# Extracting stage race: race/giro-ciclistico-d-italia/2022/stage-7
# Extracting 1day race:: race/circuit-des-xi-villes/2022
# Extracting 1day race:: race/mont-ventoux-denivele-challenge/2022
# Extracting stage race: race/la-route-d-occitanie/2022/stage-1
# Extracting stage race: race/la-route-d-occitanie/2022/stage-2
# Extracting stage race: race/la-route-d-occitanie/2022/stage-3
# Extracting stage race: race/la-route-d-occitanie/2022/stage-4
# NC race: race/nc-finland-itt/2022
# Extracting stage race: race/tour-du-pays-de-montbeliard/2022/stage-1
# Extracting stage race: race/giro-ciclistico-della-valle-d-aosta-mont-blanc/2022/stage-4
# Extracting stage race: race/giro-ciclistico-della-valle-d-aosta-mont-blanc/2022/stage-5
# NC race: race/national-championships-czech-republic-u23-road-rac/2022
# NC race: race/national-championships-slovakia-u23-road-race/2022
# Extracting stage race: race/gp-cycliste-de-gemenc/2022/stage-1
# Extracting stage race: race/gp-cycliste-de-gemenc/2022/stage-2
# Extracting 1day race:: race/grand-prix-erciyes-mimar-sinan-me/2022
# Extracting 1day race:: race/visegrad-4-bicycle-race-gp-hungary/2022
# Extracting 1day race:: race/vn-kranja-memorijal-filipa-majcna/2022
# Extracting 1day race:: race/grand-prix-de-la-ville-de-perenchies/2022
# Extracting 1day race:: race/grand-prix-kayseri-me/2022
# Extracting 1day race:: race/visegrad-4-bicycle-race-gp-slovakia/2022
# Extracting 1day race:: race/prueba-villafranca/2022
# Extraction failed: race/memorial-andrzeja-trochanowskiego/2022
# Extracting stage race: race/vuelta-a-castilla-y-leon/2022/stage-1
# Extracting stage race: race/vuelta-a-castilla-y-leon/2022/stage-2
# Extracting stage race: race/dookola-mazowsza/2022/stage-1
# Extracting stage race: race/dookola-mazowsza/2022/stage-2
# Extracting stage race: race/dookola-mazowsza/2022/stage-3
# Extracting stage race: race/dookola-mazowsza/2022/stage-4
# Extracting stage race: race/tour-alsace/2022/stage-1
# Extraction failed: race/tour-alsace/2022
# Extracting stage race: race/kreiz-breizh-elites/2022/stage-1
# Extraction failed: race/kreiz-breizh-elites/2022
# Extracting 1day race:: race/circuito-de-getxo/2022
# Extracting 1day race:: race/grand-prix-yahyali/2022
# Extracting 1day race:: race/puchar-ministra-obrony-narodowej/2022
# Extracting stage race: race/sazka-tour/2022/stage-1
# Extracting stage race: race/sazka-tour/2022/stage-2
# Extracting stage race: race/sazka-tour/2022/stage-3
# Extracting stage race: race/sazka-tour/2022/stage-4
# Extracting 1day race:: race/commonwealth-games-itt2/2022
# Extracting 1day race:: race/la_maurienne /2022
# Extracting 1day race:: race/scandinavian-race-uppsala/2022
# Extracting 1day race:: race/gp-jef-scherens/2022
# Extracting 1day race:: race/commonwealth-games/2022
# NC race: race/nc-france-u23/2022
# NC race: race/nc-france-itt-u23/2022

# %%
results_df = pd.concat(results)
results_df = results_df.pivot_table(index="Race", columns="Rider", values="UCI", aggfunc="mean")
results_df.columns = [col.lower() for col in results_df.columns]

# %%
results_df.shape
# Out:
# (272, 5956)

# %%
from google.colab import files

results_df.to_csv('race_results.csv', index=True)

files.download('race_results.csv')

# %%
# year = "2022"
# circuit=13
# header = {
#     "User-Agent": "Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/50.0.2661.75 Safari/537.36",
#     "X-Requested-With": "XMLHttpRequest"
#   }
# base_url = "https://www.procyclingstats.com/"
# r = requests.get(f"{base_url}races.php?year={year}&circuit={circuit}&class=&filter=Filter", headers=header)

# soup = BeautifulSoup(r.content)

# href = []

# for line in soup.find_all('a'):
#   href.append(line.get('href'))


# race_url = [line for line in href if line.find("race/") == 0]
# race_url = [line for line in race_url if line.find(year) == (len(line)-4)]
# race_url

# results = []

# for race in race_url:
#   r = requests.get(base_url + race, headers=header)
#   time.sleep(2)
#   print(race)
#   result = pd.read_html(r.text)[0]
#   if "GC" not in result.columns:
#     aux = result[["Rider", "Pnt"]]
#     aux["Race"] = race
#     aux["Year"] = year
#     results.append(aux)
  
# results = pd.concat(results)
