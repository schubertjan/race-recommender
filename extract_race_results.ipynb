# %%
import requests 
import time
import pandas as pd
import numpy as np
import tensorflow as tf

from tensorflow import keras
from bs4 import BeautifulSoup

# %%
def extract_results(year: str, circuit: int) -> pd.DataFrame:

  header = {
    "User-Agent": "Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/50.0.2661.75 Safari/537.36",
    "X-Requested-With": "XMLHttpRequest"
  }

  base_url = "https://www.procyclingstats.com/"
  r = requests.get(f"{base_url}races.php?year={year}&circuit={circuit}&class=&filter=Filter", headers=header)

  soup = BeautifulSoup(r.content)

  href = []

  for line in soup.find_all('a'):
      href.append(line.get('href'))
    
  race_url = [line for line in href if line.find("race/") == 0]
  race_url = [line for line in race_url if line.find(year) == (len(line)-4)]

  results = []

  for race in race_url:
    # dont use nc
    if ("nc-" in race) | ("national-championships" in race):
      print(f"NC race: {race}")
    else:  
      try:
        r = requests.get(base_url + race, headers=header)
        time.sleep(3)
        result = pd.read_html(r.text)[0]
        if "GC" not in result.columns:
          # do some data cleaning
          for index, row in result.iterrows():
            # clean rider names
            result.loc[index, "Rider"] = row["Rider"].replace(row["Team"], "")
            # make sure we have 0 when participated and NaN when not participated
            if (~row[["Rnk"]].isin(["DNF", "DNS"])[0]) & row[["UCI"]].isna()[0]:
              result.loc[index, "UCI"] = 0
            
          # extract info
          aux = result[["Rider", "UCI"]]
          # add meta data
          aux["Race"] = race.replace("race/", "").replace(f"/{year}", "")
          aux["Year"] = year
          results.append(aux)
          print(f"Extracting: {race}")
        else:
          print(f"Stage race: {race}")
      except:
        print(f"Extraction failed: {race}")
    
  return pd.concat(results)

def stand(x):
  return (x-np.nanmean(x)) / np.nanstd(x)

# %%
def cofi_cost_func(X, W, b, Y, R, lambda_):
    """
    Returns the cost for the content-based filtering
    Vectorized for speed. Uses tensorflow operations to be compatible with custom training loop.
    Args:
      X (ndarray (num_movies,num_features)): matrix of item features
      W (ndarray (num_users,num_features)) : matrix of user parameters
      b (ndarray (1, num_users)            : vector of user parameters
      Y (ndarray (num_movies,num_users)    : matrix of user ratings of movies
      R (ndarray (num_movies,num_users)    : matrix, where R(i, j) = 1 if the i-th movies was rated by the j-th user
      lambda_ (float): regularization parameter
    Returns:
      J (float) : Cost
    """
    f_x = tf.linalg.matmul(X, tf.transpose(W)) + b
    E = (f_x - Y)**2
    j = E*R
    J = 0.5 * tf.reduce_sum(j) + (lambda_/2) * (tf.reduce_sum(X**2) + tf.reduce_sum(W**2))
    return J

# %%
years = ["2020", "2021", "2022"]
circuits = [1, 13]
results = []
for year in years:
  for circuit in circuits:
    try: 
      results.append(extract_results(year=year, circuit=circuit))
    except:
      pass
# Out:
# Stage race: race/tour-down-under/2020
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:45: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# Extracting: race/great-ocean-race/2020
# Stage race: race/uae-tour/2020
# Extracting: race/omloop-het-nieuwsblad/2020
# Stage race: race/paris-nice/2020
# Extracting: race/strade-bianche/2020
# Stage race: race/tour-de-pologne/2020
# Extracting: race/milano-sanremo/2020
# Stage race: race/dauphine/2020
# Extracting: race/il-lombardia/2020
# Extracting: race/bretagne-classic/2020
# Stage race: race/tour-de-france/2020
# Stage race: race/tirreno-adriatico/2020
# Stage race: race/benelux-tour/2020
# Extracting: race/la-fleche-wallone/2020
# Stage race: race/giro-d-italia/2020
# Extracting: race/liege-bastogne-liege/2020
# Extracting: race/gent-wevelgem/2020
# Extracting: race/ronde-van-vlaanderen/2020
# Stage race: race/vuelta-a-espana/2020
# Extracting: race/oxyclean-classic-brugge-de-panne/2020
# Extracting: race/gp-belek/2020
# Extracting: race/trofeo-cala-millor/2020
# Extracting: race/deia-trophy/2020
# Extracting: race/trofeo-andratx-mirador-d-es-colomer/2020
# Extracting: race/gp-d-ouverture/2020
# Extracting: race/trofeo-palma/2020
# Stage race: race/vuelta-a-la-comunidad-valenciana/2020
# Stage race: race/etoile-de-besseges/2020
# Extracting: race/gp-manavgat/2020
# Stage race: race/tour-cycliste-international-la-provence/2020
# Extracting: race/grand-prix-alanya/2020
# Stage race: race/vuelta-ciclista-a-la-region-de-murcia/2020
# Extracting: race/grand-prix-gazipasa/2020
# Extracting: race/clasica-de-almeria/2020
# Extracting: race/trofeo-laigueglia/2020
# Extracting: race/gp-antalya/2020
# Stage race: race/volta-ao-algarve/2020
# Stage race: race/ruta-del-sol/2020
# Stage race: race/tour-of-antalya/2020
# Stage race: race/tour-des-alpes-maritimes-et-du-var/2020
# Stage race: race/manavgat-side-junior/2020
# Extracting: race/faun-ardeche-classic/2020
# Extracting: race/ster-van-zwolle/2020
# Extracting: race/grand-prix-velo-alanya/2020
# Extracting: race/kuurne-brussel-kuurne/2020
# Extracting: race/la-drome-classic/2020
# Extracting: race/grand-prix-manavgat-side/2020
# Extracting: race/grand-prix-manavgat-side-we/2020
# Extracting: race/international-rhodes-gp/2020
# Extracting: race/gp-samyn/2020
# Extracting: race/trofej-umag-umag-trophy/2020
# Stage race: race/tour-of-rhodes/2020
# Extracting: race/grote-prijs-jean-pierre-monsere/2020
# Extracting: race/dorpenomloop-rucphen/2020
# Extracting: race/gp-de-la-ville-de-lillers/2020
# Extracting: race/porec-trophy-trofej-porec/2020
# NC race: race/nc-poland-u23-itt/2020
# NC race: race/nc-slovenia/2020
# NC race: race/nc-slovenia-itt/2020
# NC race: race/nc-switzerland-itt/2020
# NC race: race/nc-switzerland-u23-itt/2020
# Stage race: race/dookola-mazowsza/2020
# NC race: race/nc-croatia-itt/2020
# NC race: race/nc-croatia-u23-itt/2020
# NC race: race/nc-croatia/2020
# Extracting: race/puchar-ministra-obrony-narodowej/2020
# Stage race: race/sibiu-cycling-tour/2020
# NC race: race/nc-belarus-itt/2020
# NC race: race/nc-belarus-u23-itt/2020
# NC race: race/nc-norway-itt/2020
# NC race: race/nc-sweden-itt/2020
# Stage race: race/in-the-footsteps-of-the-romans/2020
# NC race: race/nc-greece-u23-itt/2020
# NC race: race/nc-belarus/2020
# Extracting: race/vn-kranja-memorijal-filipa-majcna/2020
# NC race: race/nc-greece-u23/2020
# Stage race: race/vuelta-a-burgos/2020
# Stage race: race/tour-of-bulgaria/2020
# Stage race: race/la-route-d-occitanie/2020
# NC race: race/nc-italy-u23-itt/2020
# Extracting: race/circuito-de-getxo/2020
# Extracting: race/gran-trittico-lombardo/2020
# Extracting: race/milano-torino/2020
# Stage race: race/tour-of-szeklerland/2020
# Extracting: race/uec-road-european-championships-itt/2020
# Extraction failed: race/european-continental-championships-u23-itt/2020
# Extracting: race/uec-road-european-championships/2020
# Stage race: race/tour-du-poitou-charentes-et-de-la-vienne/2020
# Extracting: race/european-championships/2020
# Extraction failed: race/european-continental-championships-mixed-relay-ttt/2020
# Extracting: race/druivenkoers-overijse/2020
# Stage race: race/tour-de-hongrie/2020
# Extracting: race/trofeo-matteotti/2020
# Stage race: race/giro-ciclistico-d-italia/2020
# NC race: race/national-championships-kosovo-u23-road-race/2020
# Extracting: race/brussels-cycling-classic/2020
# Extracting: race/memorial-marco-pantani/2020
# Extracting: race/carpathia-couriers-paths/2020
# Stage race: race/settimana-internazionale-coppi-e-bartali/2020
# Stage race: race/tour-de-serbie/2020
# Stage race: race/baltyk-karkonosze-tour/2020
# Extracting: race/grand-prix-develi/2020
# Stage race: race/banja-luka-belgrade-i/2020
# NC race: race/nc-greece-itt/2020
# Extracting: race/grand-prix-cappadocia/2020
# Extracting: race/hafjell-gp/2020
# NC race: race/nc-kosovo-itt/2020
# Extracting: race/grand-prix-mount-erciyes-2200-mt/2020
# Extracting: race/lillehammer-gp/2020
# NC race: race/national-championships-kosovo-u23-itt/2020
# NC race: race/nc-greece/2020
# NC race: race/nc-kosovo/2020
# NC race: race/nc-latvia/2020
# Extracting: race/tour-du-doubs/2020
# Extracting: race/grand-prix-world-s-best-high-altitude/2020
# Extraction failed: race/gylne-gutuer/2020
# NC race: race/nc-germany-u23-itt/2020
# Stage race: race/romanian-cycling-tour/2020
# Stage race: race/course-cycliste-de-solidarnosc/2020
# NC race: race/nc-denmark-u23-itt/2020
# NC race: race/nc-latvia-itt/2020
# NC race: race/nc-serbia/2020
# NC race: race/nc-latvia-u23-itt/2020
# NC race: race/nc-norway-u23/2020
# Stage race: race/orlen-nations-grand-prix/2020
# NC race: race/nc-italy-u23/2020
# Extracting: race/antwerp-port-epic/2020
# NC race: race/nc-denmark-u23/2020
# Extracting: race/grand-prix-velo-erciyes-me/2020
# Stage race: race/tour-de-luxembourg/2020
# Extracting: race/grand-prix-central-anatolia/2020
# Extracting: race/giro-di-toscana/2020
# Stage race: race/okolo-slovenska/2020
# Extracting: race/gp-citta-di-peccioli/2020
# Stage race: race/ronde-de-l-isard/2020
# Stage race: race/tour-of-malopolska/2020
# NC race: race/nc-moldova-itt/2020
# Extracting: race/giro-del-appennino/2020
# NC race: race/nc-moldova/2020
# Stage race: race/gp-int-torres-vedras/2020
# Extracting: race/gooikse-pijl/2020
# Extracting: race/gp-d-isbergues/2020
# Extracting: race/gp-industria-e-commercio2/2020
# NC race: race/nc-belgium/2020
# NC race: race/nc-turkey-itt/2020
# NC race: race/national-championships-turkey-u23-itt/2020
# Extracting: race/paris-camembert/2020
# NC race: race/nc-turkey/2020
# Extracting: race/world-championship-we/2020
# Stage race: race/tour-of-mevlana/2020
# Extracting: race/world-championship/2020
# Extracting: race/paris-chauny-classique/2020
# Stage race: race/volta-a-portugal/2020
# NC race: race/nc-ireland-itt/2020
# NC race: race/nc-ireland-itt-u23/2020
# NC race: race/nc-denmark-itt/2020
# NC race: race/nc-ireland/2020
# NC race: race/nc-sweden/2020
# Extracting: race/piccolo-giro-di-lombardia/2020
# Extracting: race/brabantse-pijl/2020
# Stage race: race/giro-della-regione-friuli-venezia-giulia/2020
# Extracting: race/visegrad-4-bicycle-race-gp-slovakia/2020
# Extracting: race/paris-tours/2020
# Extracting: race/paris-tours-espoirs/2020
# Extracting: race/prueba-villafranca/2020
# Extraction failed: race/scheldeprijs/2020
# NC race: race/nc-cyprus-itt/2020
# NC race: race/nc-belgium-u23/2020
# NC race: race/nc-cyprus/2020
# NC race: race/nc-france-itt-u23/2020
# NC race: race/nc-france-u23/2020
# NC race: race/nc-switserland/2020
# NC race: race/nc-israel-itt/2020
# NC race: race/national-championships-u23-itt/2020
# Stage race: race/uae-tour/2021
# Extracting: race/omloop-het-nieuwsblad/2021
# Extracting: race/strade-bianche/2021
# Stage race: race/paris-nice/2021
# Stage race: race/tirreno-adriatico/2021
# Extracting: race/milano-sanremo/2021
# Stage race: race/volta-a-catalunya/2021
# Extracting: race/oxyclean-classic-brugge-de-panne/2021
# Extracting: race/e3-harelbeke/2021
# Extracting: race/gent-wevelgem/2021
# Extracting: race/dwars-door-vlaanderen/2021
# Extracting: race/ronde-van-vlaanderen/2021
# Stage race: race/itzulia-basque-country/2021
# Extracting: race/amstel-gold-race/2021
# Extracting: race/la-fleche-wallone/2021
# Extracting: race/liege-bastogne-liege/2021
# Stage race: race/tour-de-romandie/2021
# Stage race: race/giro-d-italia/2021
# Stage race: race/dauphine/2021
# Stage race: race/tour-de-suisse/2021
# Stage race: race/tour-de-france/2021
# Extracting: race/san-sebastian/2021
# Stage race: race/tour-de-pologne/2021
# Stage race: race/vuelta-a-espana/2021
# Extracting: race/bretagne-classic/2021
# Stage race: race/benelux-tour/2021
# Extracting: race/Eschborn-Frankfurt/2021
# Extracting: race/paris-roubaix/2021
# Extracting: race/il-lombardia/2021
# Extracting: race/gp-de-valence/2021
# Extracting: race/gp-d-ouverture/2021
# Stage race: race/etoile-de-besseges/2021
# Extracting: race/grand-prix-alanya/2021
# Extracting: race/grand-prix-gazipasa/2021
# Stage race: race/tour-des-alpes-maritimes-et-du-var/2021
# Extracting: race/grand-prix-manavgat-side/2021
# Extracting: race/grand-prix-velo-alanya/2021
# Extracting: race/gp-samyn/2021
# Extracting: race/trofej-umag-umag-trophy/2021
# Extracting: race/grand-prix-mediterrennean/2021
# Extracting: race/grote-prijs-jean-pierre-monsere/2021
# Extracting: race/grand-prix-gundogmus-me/2021
# Extracting: race/porec-trophy-trofej-porec/2021
# Stage race: race/istarsko-proljece-istrian-spring-trophy/2021
# Extracting: race/paris-troyes/2021
# Extracting: race/per-sempre-alfredo/2021
# Extracting: race/gp-izola-butan-plin/2021
# Stage race: race/settimana-internazionale-coppi-e-bartali/2021
# Extracting: race/cholet-pays-de-loire/2021
# Extracting: race/gp-adria-mobil/2021
# Stage race: race/tour-of-mevlana/2021
# Extracting: race/la-roue-tourangelle/2021
# NC race: race/nc-romania/2021
# NC race: race/nc-belgium-u23/2021
# NC race: race/nc-romania-u23/2021
# Stage race: race/tour-du-poitou-charentes-et-de-la-vienne/2021
# Extracting: race/druivenkoers-overijse/2021
# NC race: race/nc-moldova-itt/2021
# Stage race: race/tour-du-pays-de-montbeliard/2021
# NC race: race/nc-moldova/2021
# Extraction failed: race/adriatic-race/2021
# Extraction failed: race/himmerland-rundt/2021
# Stage race: race/carpathia-couriers-paths/2021
# Extracting: race/gp-de-la-somme/2021
# Extracting: race/skive-lobet/2021
# Extracting: race/ronde-van-de-achterhoek/2021
# Stage race: race/romanian-cycling-tour/2021
# Stage race: race/flanders-tomorrow-tour/2021
# Extracting: race/classic-grand-besancon-doubs/2021
# Stage race: race/paris-arras-tour/2021
# Stage race: race/giro-della-regione-friuli-venezia-giulia/2021
# Extracting: race/tour-du-jura-cycliste/2021
# Extracting: race/tour-du-doubs/2021
# Extraction failed: race/european-continental-championships-mixed-relay-ttt/2021
# Extracting: race/uec-road-european-championships-itt/2021
# Extracting: race/european-continental-championships-u23-itt/2021
# Stage race: race/okolo-jiznich-cech/2021
# Stage race: race/tour-de-serbie/2021
# Extracting: race/european-championships/2021
# Extracting: race/uec-road-european-championships/2021
# Extracting: race/antwerp-port-epic/2021
# Extracting: race/giro-di-toscana/2021
# Stage race: race/okolo-slovenska/2021
# Extracting: race/kampioenschap-van-vlaanderen/2021
# Extracting: race/memorial-marco-pantani/2021
# Extraction failed: race/liege-bastogne-liege-u23/2021
# Extracting: race/zodc-zuidenveld-tour/2021
# Extracting: race/gooikse-pijl/2021
# Extracting: race/gp-d-isbergues/2021
# Extracting: race/trofeo-matteotti/2021
# Stage race: race/le-tour-de-bretagne/2021
# Extracting: race/omloop-van-het-houtland-lichtervelde/2021
# Extracting: race/paris-chauny-classique/2021
# Extracting: race/dorpenomloop-rucphen/2021
# Stage race: race/tour-of-croatia/2021
# Stage race: race/giro-di-sicilia/2021
# Extracting: race/ruota-d-oro-gp-festa-del-perdono/2021
# Stage race: race/ronde-de-l-isard/2021
# NC race: race/nc-ireland-itt/2021
# NC race: race/nc-ireland-itt-u23/2021
# Extracting: race/route-adelie-de-vitre/2021
# Extracting: race/classic-loire-atlantique/2021
# Extracting: race/lillehammer-gp/2021
# NC race: race/nc-ireland/2021
# Extracting: race/gylne-gutuer/2021
# Extracting: race/piccolo-giro-di-lombardia/2021
# Extracting: race/memorial-frank-vandenbroucke/2021
# Extracting: race/paris-bourges/2021
# Stage race: race/circuit-des-ardennes-international/2021
# Extracting: race/tour-de-vendee/2021
# Extracting: race/paris-tours-espoirs/2021
# Extracting: race/coppa-agostoni/2021
# Extracting: race/giro-del-veneto/2021
# NC race: race/nc-cyprus-itt/2021
# NC race: race/nc-great-britain-itt/2021
# NC race: race/nc-great-britain-u23-itt/2021
# NC race: race/nc-denmark-u23-itt/2021
# Extracting: race/ster-van-zwolle/2021
# Extracting: race/boucles-de-l-aulne/2021
# Extracting: race/chrono-des-nations/2021
# NC race: race/nc-cyprus/2021
# Extracting: race/european-continental-championships-wu23-itt/2022
# Extracting: race/european-championship-mj/2022
# Extracting: race/european-continental-championships-wj-road-race/2022
# Extracting: race/gp-czech-republic/2022
# Extracting: race/2-districtenpijl-ekeren-deurne-me/2022
# Extracting: race/european-championships/2022
# Extracting: race/european-championship-we-u23/2022
# Extracting: race/gp-de-la-ville-de-nogent-sur-oise/2022
# Extracting: race/visegrad-4-bicycle-race-gp-polski-via-odra/2022
# Stage race: race/giro-ciclistico-della-valle-d-aosta-mont-blanc/2022
# NC race: race/national-championships-czech-republic-u23-road-rac/2022
# NC race: race/national-championships-slovakia-u23-road-race/2022
# Stage race: race/gp-cycliste-de-gemenc/2022
# Extracting: race/grand-prix-erciyes-mimar-sinan-me/2022
# Extracting: race/visegrad-4-bicycle-race-gp-hungary/2022
# Extracting: race/vn-kranja-memorijal-filipa-majcna/2022
# Extracting: race/grand-prix-de-la-ville-de-perenchies/2022
# Extracting: race/grand-prix-kayseri-me/2022
# Extracting: race/visegrad-4-bicycle-race-gp-slovakia/2022
# Extracting: race/prueba-villafranca/2022
# Extraction failed: race/memorial-andrzeja-trochanowskiego/2022
# Stage race: race/vuelta-a-castilla-y-leon/2022
# Stage race: race/dookola-mazowsza/2022
# Stage race: race/tour-alsace/2022
# Stage race: race/kreiz-breizh-elites/2022
# Extracting: race/circuito-de-getxo/2022
# Extracting: race/grand-prix-yahyali/2022
# Extracting: race/puchar-ministra-obrony-narodowej/2022
# Stage race: race/sazka-tour/2022
# Extracting: race/commonwealth-games-itt2/2022
# Extracting: race/la_maurienne /2022
# Extracting: race/scandinavian-race-uppsala/2022
# Extracting: race/gp-jef-scherens/2022
# Extracting: race/commonwealth-games/2022
# NC race: race/nc-france-u23/2022

# %%
results_df = pd.concat(results)
results_df = results_df.pivot_table(index="Race", columns="Rider", values="UCI", aggfunc="mean")

# %%
results_df.shape
# Out:
# (196, 5087)

# %%
from google.colab import files

results_df.to_csv('race_results.csv', index=True)

files.download('race_results.csv')

# %%
Y = results_df.to_numpy()
Y_norm = results_df.apply(lambda row: stand(row), axis=1).to_numpy()
Y_norm[results_df.isna().to_numpy()] = -99

R = np.zeros(Y.shape)
R[results_df.notna().to_numpy()] = 1
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-0ea7500e6697> in <module>()
# ----> 1 Y = results_df.to_numpy()
#       2 Y_norm = results_df.apply(lambda row: stand(row), axis=1).to_numpy()
#       3 Y_norm[results_df.isna().to_numpy()] = -99
#       4
#       5 R = np.zeros(Y.shape)
#
# NameError: name 'results_df' is not defined
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-0ea7500e6697> in <module>()
# ----> 1 Y = results_df.to_numpy()
#       2 Y_norm = results_df.apply(lambda row: stand(row), axis=1).to_numpy()
#       3 Y_norm[results_df.isna().to_numpy()] = -99
#       4
#       5 R = np.zeros(Y.shape)
#
# NameError: name 'results_df' is not defined

# %%
Y_norm
# Out:
# nan

# %%
#  Useful Values
num_races, num_riders = Y.shape
num_features = 100
lambda_ = 0.001
# Set Initial Parameters (W, X), use tf.Variable to track these variables
tf.random.set_seed(1234) # for consistent results
W = tf.Variable(tf.random.normal((num_riders,  num_features),dtype=tf.float64),  name='W')
X = tf.Variable(tf.random.normal((num_races, num_features),dtype=tf.float64),  name='X')
b = tf.Variable(tf.random.normal((1,          num_riders),   dtype=tf.float64),  name='b')

# Instantiate an optimizer.
optimizer = keras.optimizers.Adam(learning_rate=1e-1)

iterations = 200
lambda_ = 1
for iter in range(iterations):
    # Use TensorFlow’s GradientTape
    # to record the operations used to compute the cost 
    with tf.GradientTape() as tape:

        # Compute the cost (forward pass included in cost)
        cost_value = cofi_cost_func(X, W, b, Y_norm, R, lambda_)

    # Use the gradient tape to automatically retrieve
    # the gradients of the trainable variables with respect to the loss
    grads = tape.gradient( cost_value, [X,W,b] )

    # Run one step of gradient descent by updating
    # the value of the variables to minimize the loss.
    optimizer.apply_gradients( zip(grads, [X,W,b]) )

    # Log periodically.
    if iter % 20 == 0:
        print(f"Training loss at iteration {iter}: {cost_value:0.1f}")
# Out:
# Training loss at iteration 0: nan
# Training loss at iteration 20: nan
# Training loss at iteration 40: nan
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-49-d42c8c1d8d4c> in <module>()
#      24     # Use the gradient tape to automatically retrieve
#      25     # the gradients of the trainable variables with respect to the loss
# ---> 26     grads = tape.gradient( cost_value, [X,W,b] )
#      27
#      28     # Run one step of gradient descent by updating
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/eager/backprop.py in gradient(self, target, sources, output_gradients, unconnected_gradients)
#    1085         output_gradients=output_gradients,
#    1086         sources_raw=flat_sources_raw,
# -> 1087         unconnected_gradients=unconnected_gradients)
#    1088
#    1089     if not self._persistent:
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/eager/imperative_grad.py in imperative_grad(tape, target, sources, output_gradients, sources_raw, unconnected_gradients)
#      71       output_gradients,
#      72       sources_raw,
# ---> 73       compat.as_str(unconnected_gradients.value))
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/eager/backprop.py in _gradient_function(op_name, attr_tuple, num_inputs, inputs, outputs, out_grads, skip_input_indices, forward_pass_name_scope)
#     154       gradient_name_scope += forward_pass_name_scope + "/"
#     155     with ops.name_scope(gradient_name_scope):
# --> 156       return grad_fn(mock_op, *out_grads)
#     157   else:
#     158     return grad_fn(mock_op, *out_grads)
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/ops/math_grad.py in _PowGrad(op, grad)
#    1505       x = math_ops.conj(x)
#    1506       y = math_ops.conj(y)
# -> 1507       return grad * y * math_ops.pow(x, y - 1), None
#    1508
#    1509   except AttributeError:
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/util/traceback_utils.py in error_handler(*args, **kwargs)
#     148     filtered_tb = None
#     149     try:
# --> 150       return fn(*args, **kwargs)
#     151     except Exception as e:
#     152       filtered_tb = _process_traceback_frames(e.__traceback__)
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/util/dispatch.py in op_dispatch_handler(*args, **kwargs)
#    1080       # Fallback dispatch system (dispatch v1):
#    1081       try:
# -> 1082         return dispatch_target(*args, **kwargs)
#    1083       except (TypeError, ValueError):
#    1084         # Note: convert_to_eager_tensor currently raises a ValueError, not a
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/ops/math_ops.py in pow(x, y, name)
#     692   """
#     693   with ops.name_scope(name, "Pow", [x]) as name:
# --> 694     return gen_math_ops._pow(x, y, name=name)
#     695
#     696
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/ops/gen_math_ops.py in _pow(x, y, name)
#    7094     try:
#    7095       _result = pywrap_tfe.TFE_Py_FastPathExecute(
# -> 7096         _ctx, "Pow", name, x, y)
#    7097       return _result
#    7098     except _core._NotOkStatusException as e:
#
# KeyboardInterrupt:

# %%
# year = "2022"
# circuit=13
# header = {
#     "User-Agent": "Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/50.0.2661.75 Safari/537.36",
#     "X-Requested-With": "XMLHttpRequest"
#   }
# base_url = "https://www.procyclingstats.com/"
# r = requests.get(f"{base_url}races.php?year={year}&circuit={circuit}&class=&filter=Filter", headers=header)

# soup = BeautifulSoup(r.content)

# href = []

# for line in soup.find_all('a'):
#   href.append(line.get('href'))


# race_url = [line for line in href if line.find("race/") == 0]
# race_url = [line for line in race_url if line.find(year) == (len(line)-4)]
# race_url

# results = []

# for race in race_url:
#   r = requests.get(base_url + race, headers=header)
#   time.sleep(2)
#   print(race)
#   result = pd.read_html(r.text)[0]
#   if "GC" not in result.columns:
#     aux = result[["Rider", "Pnt"]]
#     aux["Race"] = race
#     aux["Year"] = year
#     results.append(aux)
  
# results = pd.concat(results)
