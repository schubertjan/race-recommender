# %%
import pandas as pd
import numpy as np
import tensorflow as tf

from tensorflow import keras

# %%
def stand(x):
  return (x-np.nanmean(x)) / np.nanstd(x)

def cofi_cost_func(X, W, b, Y, R, lambda_):
    """
    Returns the cost for the content-based filtering
    Vectorized for speed. Uses tensorflow operations to be compatible with custom training loop.
    Args:
      X (ndarray (num_movies,num_features)): matrix of item features
      W (ndarray (num_users,num_features)) : matrix of user parameters
      b (ndarray (1, num_users)            : vector of user parameters
      Y (ndarray (num_movies,num_users)    : matrix of user ratings of movies
      R (ndarray (num_movies,num_users)    : matrix, where R(i, j) = 1 if the i-th movies was rated by the j-th user
      lambda_ (float): regularization parameter
    Returns:
      J (float) : Cost
    """
    f_x = tf.linalg.matmul(X, tf.transpose(W)) + b
    E = (f_x - Y)**2
    j = E*R
    J = 0.5 * tf.reduce_sum(j) + (lambda_/2) * (tf.reduce_sum(X**2) + tf.reduce_sum(W**2))
    return J

# %%
results_df = pd.read_csv("https://raw.githubusercontent.com/schubertjan/race-recommender/master/race_results.csv")
results_df = results_df.set_index("Race")
results_df.columns = [col.lower() for col in results_df.columns]
results_df
# Out:
#                                        aagaard hansen tobias  aalerud katrine  \
# Race
# 2-districtenpijl-ekeren-deurne-me                        NaN              NaN
# Eschborn-Frankfurt                                       NaN              NaN
# albani-classic-fyen-rundt                                NaN              NaN
# amstel-gold-2021                                         NaN              NaN
# amstel-gold-2022                                         NaN              NaN
# ...                                                      ...              ...
# vuelta-ciclista-a-la-region-de-murcia                    NaN              NaN
# world-championship                                       NaN              NaN
# world-championship-we                                    NaN             20.0
# youngster-coast-challenge                                NaN              NaN
# zodc-zuidenveld-tour                                     0.0              NaN
#
#                                        aalrust håkon  aas eirik vang  \
# Race
# 2-districtenpijl-ekeren-deurne-me                NaN             NaN
# Eschborn-Frankfurt                               NaN             NaN
# albani-classic-fyen-rundt                        NaN             NaN
# amstel-gold-2021                                 NaN             NaN
# amstel-gold-2022                                 NaN             NaN
# ...                                              ...             ...
# vuelta-ciclista-a-la-region-de-murcia            NaN             NaN
# world-championship                               NaN             NaN
# world-championship-we                            NaN             NaN
# youngster-coast-challenge                        NaN             NaN
# zodc-zuidenveld-tour                             NaN             NaN
#
#                                        aasheim ludvig  aaskov pallesen jeppe  \
# Race
# 2-districtenpijl-ekeren-deurne-me                 NaN                    NaN
# Eschborn-Frankfurt                                NaN                    NaN
# albani-classic-fyen-rundt                         NaN                    NaN
# amstel-gold-2021                                  NaN                    NaN
# amstel-gold-2022                                  NaN                    NaN
# ...                                               ...                    ...
# vuelta-ciclista-a-la-region-de-murcia             NaN                    NaN
# world-championship                                NaN                    NaN
# world-championship-we                             NaN                    NaN
# youngster-coast-challenge                         NaN                    NaN
# zodc-zuidenveld-tour                              NaN                    NaN
#
#                                        aasvold kristian  abay burak  \
# Race
# 2-districtenpijl-ekeren-deurne-me                   NaN         NaN
# Eschborn-Frankfurt                                  NaN         NaN
# albani-classic-fyen-rundt                           NaN         NaN
# amstel-gold-2021                                    NaN         NaN
# amstel-gold-2022                                    NaN         NaN
# ...                                                 ...         ...
# vuelta-ciclista-a-la-region-de-murcia               NaN         NaN
# world-championship                                  NaN         NaN
# world-championship-we                               NaN         NaN
# youngster-coast-challenge                           NaN         NaN
# zodc-zuidenveld-tour                                NaN         NaN
#
#                                        abbas yaser  abbasov ibad  ...  \
# Race                                                              ...
# 2-districtenpijl-ekeren-deurne-me              NaN           NaN  ...
# Eschborn-Frankfurt                             NaN           NaN  ...
# albani-classic-fyen-rundt                      NaN           NaN  ...
# amstel-gold-2021                               NaN           NaN  ...
# amstel-gold-2022                               NaN           NaN  ...
# ...                                            ...           ...  ...
# vuelta-ciclista-a-la-region-de-murcia          NaN           NaN  ...
# world-championship                             NaN           NaN  ...
# world-championship-we                          NaN           NaN  ...
# youngster-coast-challenge                      NaN           NaN  ...
# zodc-zuidenveld-tour                           NaN           NaN  ...
#
#                                        štoček matúš  štybar zdeněk  \
# Race
# 2-districtenpijl-ekeren-deurne-me               NaN            NaN
# Eschborn-Frankfurt                              NaN            NaN
# albani-classic-fyen-rundt                       0.0            NaN
# amstel-gold-2021                                NaN            NaN
# amstel-gold-2022                                NaN           20.0
# ...                                             ...            ...
# vuelta-ciclista-a-la-region-de-murcia           NaN            NaN
# world-championship                              NaN            NaN
# world-championship-we                           NaN            NaN
# youngster-coast-challenge                       NaN            NaN
# zodc-zuidenveld-tour                            NaN            NaN
#
#                                        ťoupalík adam  ťoupalík jakub  \
# Race
# 2-districtenpijl-ekeren-deurne-me                NaN             NaN
# Eschborn-Frankfurt                               NaN             NaN
# albani-classic-fyen-rundt                        NaN             NaN
# amstel-gold-2021                                 NaN             NaN
# amstel-gold-2022                                 NaN             NaN
# ...                                              ...             ...
# vuelta-ciclista-a-la-region-de-murcia            NaN             NaN
# world-championship                               0.0             NaN
# world-championship-we                            NaN             NaN
# youngster-coast-challenge                        NaN             NaN
# zodc-zuidenveld-tour                             NaN             NaN
#
#                                        żelazowski michał  żuber adam  \
# Race
# 2-districtenpijl-ekeren-deurne-me                    NaN         NaN
# Eschborn-Frankfurt                                   NaN         NaN
# albani-classic-fyen-rundt                            NaN         NaN
# amstel-gold-2021                                     NaN         NaN
# amstel-gold-2022                                     NaN         NaN
# ...                                                  ...         ...
# vuelta-ciclista-a-la-region-de-murcia                NaN         NaN
# world-championship                                   NaN         NaN
# world-championship-we                                NaN         NaN
# youngster-coast-challenge                            NaN         NaN
# zodc-zuidenveld-tour                                 NaN         NaN
#
#                                        żurek jakub  žigart urška  žumer matic  \
# Race
# 2-districtenpijl-ekeren-deurne-me              NaN           NaN          NaN
# Eschborn-Frankfurt                             NaN           NaN          NaN
# albani-classic-fyen-rundt                      NaN           NaN          NaN
# amstel-gold-2021                               NaN           NaN          NaN
# amstel-gold-2022                               NaN           NaN          NaN
# ...                                            ...           ...          ...
# vuelta-ciclista-a-la-region-de-murcia          NaN           NaN          NaN
# world-championship                             NaN           NaN          NaN
# world-championship-we                          NaN           0.0          NaN
# youngster-coast-challenge                      NaN           NaN          NaN
# zodc-zuidenveld-tour                           NaN           NaN          NaN
#
#                                        țvetcov serghei
# Race
# 2-districtenpijl-ekeren-deurne-me                  NaN
# Eschborn-Frankfurt                                 NaN
# albani-classic-fyen-rundt                          NaN
# amstel-gold-2021                                   NaN
# amstel-gold-2022                                   NaN
# ...                                                ...
# vuelta-ciclista-a-la-region-de-murcia              NaN
# world-championship                                 NaN
# world-championship-we                              NaN
# youngster-coast-challenge                          NaN
# zodc-zuidenveld-tour                               NaN
#
# [196 rows x 5087 columns]

# %%
Y = results_df.to_numpy()
Y_norm = results_df.apply(lambda row: stand(np.log(row + 1)), axis=1).to_numpy()
Y_norm[np.isnan(Y_norm)] = -99

Y_mean = np.nanmean(np.log(Y+1), axis=1)
Y_std = np.nanstd(np.log(Y+1), axis=1)

R = np.ones(Y.shape)
R[np.isnan(Y)] = 0

# %%
#  Useful Values
num_races, num_riders = Y.shape
num_features = 100
lambda_ = 1
# Set Initial Parameters (W, X), use tf.Variable to track these variables
tf.random.set_seed(1234) # for consistent results
W = tf.Variable(tf.random.normal((num_riders,  num_features),dtype=tf.float64),  name='W')
X = tf.Variable(tf.random.normal((num_races, num_features),dtype=tf.float64),  name='X')
b = tf.Variable(tf.random.normal((1,          num_riders),   dtype=tf.float64),  name='b')

# Instantiate an optimizer.
optimizer = keras.optimizers.Adam(learning_rate=1e-1)

iterations = 1000
lambda_ = 1
for iter in range(iterations):
    # Use TensorFlow’s GradientTape
    # to record the operations used to compute the cost 
    with tf.GradientTape() as tape:

        # Compute the cost (forward pass included in cost)
        cost_value = cofi_cost_func(X, W, b, Y_norm, R, lambda_)

    # Use the gradient tape to automatically retrieve
    # the gradients of the trainable variables with respect to the loss
    grads = tape.gradient( cost_value, [X,W,b] )

    # Run one step of gradient descent by updating
    # the value of the variables to minimize the loss.
    optimizer.apply_gradients( zip(grads, [X,W,b]) )

    # Log periodically.
    if iter % 20 == 0:
        print(f"Training loss at iteration {iter}: {cost_value:0.1f}")
# Out:
# Training loss at iteration 0: 3207982.9
# Training loss at iteration 20: 175152.0
# Training loss at iteration 40: 72002.5
# Training loss at iteration 60: 39691.9
# Training loss at iteration 80: 27006.5
# Training loss at iteration 100: 20741.8
# Training loss at iteration 120: 17068.6
# Training loss at iteration 140: 14655.4
# Training loss at iteration 160: 12941.4
# Training loss at iteration 180: 11654.8
# Training loss at iteration 200: 10650.9
# Training loss at iteration 220: 9846.6
# Training loss at iteration 240: 9190.0
# Training loss at iteration 260: 8647.3
# Training loss at iteration 280: 8194.4
# Training loss at iteration 300: 7813.8
# Training loss at iteration 320: 7492.1
# Training loss at iteration 340: 7218.8
# Training loss at iteration 360: 6985.7
# Training loss at iteration 380: 6786.0
# Training loss at iteration 400: 6614.3
# Training loss at iteration 420: 6466.0
# Training loss at iteration 440: 6337.5
# Training loss at iteration 460: 6225.8
# Training loss at iteration 480: 6128.2
# Training loss at iteration 500: 6042.7
# Training loss at iteration 520: 5967.6
# Training loss at iteration 540: 5901.4
# Training loss at iteration 560: 5842.8
# Training loss at iteration 580: 5790.7
# Training loss at iteration 600: 5744.4
# Training loss at iteration 620: 5703.1
# Training loss at iteration 640: 5666.1
# Training loss at iteration 660: 5632.9
# Training loss at iteration 680: 5603.1
# Training loss at iteration 700: 5576.2
# Training loss at iteration 720: 5551.8
# Training loss at iteration 740: 5529.8
# Training loss at iteration 760: 5509.8
# Training loss at iteration 780: 5491.6
# Training loss at iteration 800: 5475.0
# Training loss at iteration 820: 5459.9
# Training loss at iteration 840: 5446.1
# Training loss at iteration 860: 5433.4
# Training loss at iteration 880: 5421.8
# Training loss at iteration 900: 5411.1
# Training loss at iteration 920: 5401.2
# Training loss at iteration 940: 5392.1
# Training loss at iteration 960: 5383.7
# Training loss at iteration 980: 5375.9

# %%
# Make a prediction using trained weights and biases
p = np.matmul(X.numpy(), np.transpose(W.numpy())) + b.numpy()

#restore the mean
pm_e = np.multiply(p, Y_std.reshape(p.shape[0], 1)) + Y_mean.reshape(p.shape[0], 1)
pm = np.exp(pm_e)-1

# %%
rider_name = "kristoff alexander"
j = results_df.columns.isin([rider_name])
rider = np.arange(0, results_df.shape[1])[j]

check = pd.DataFrame(data={"y_hat": pm[:, rider].reshape(-1,), "y": results_df.iloc[:, rider].values.reshape(-1,)}, index = results_df.index)
check.dropna()
# Out:
#                                             y_hat           y
# Race
# Eschborn-Frankfurt                     183.710666  215.000000
# clasica-de-almeria                     119.320179  150.000000
# deia-trophy                             45.012842   50.000000
# dwars-door-vlaanderen                   52.906716   60.000000
# e3-harelbeke                             0.417374    0.000000
# gent-wevelgem                           38.364694   40.000000
# gp-du-canton-d-argovie                   0.115778    0.000000
# gp-jef-scherens                         59.748680   70.000000
# kuurne-brussel-kuurne                  102.029117  125.000000
# milano-sanremo                           6.813578    6.666667
# milano-torino                            0.211379    0.000000
# omloop-het-nieuwsblad                    1.309664    1.000000
# oxyclean-classic-brugge-de-panne        12.439072   12.000000
# paris-roubaix                           50.987380   50.000000
# ronde-van-vlaanderen                   130.602024  146.666667
# trofeo-alcudia                           0.143136    0.000000
# trofeo-calvia                            0.128454    0.000000
# trofeo-palma                             5.029274    5.000000
# vuelta-ciclista-a-la-region-de-murcia    2.971200    3.000000

# %%
from google.colab import files

pd.DataFrame(pm, index = results_df.index, columns=results_df.columns).to_csv("y_hat.csv", index=False)

files.download('y_hat.csv')
