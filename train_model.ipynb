# %%
import pandas as pd
import numpy as np
import tensorflow as tf

from tensorflow import keras

# %%
def stand(x):
  return (x-np.nanmean(x)) / np.nanstd(x)

def cofi_cost_func(X, W, b, Y, R, lambda_):
    """
    Returns the cost for the content-based filtering
    Vectorized for speed. Uses tensorflow operations to be compatible with custom training loop.
    Args:
      X (ndarray (num_movies,num_features)): matrix of item features
      W (ndarray (num_users,num_features)) : matrix of user parameters
      b (ndarray (1, num_users)            : vector of user parameters
      Y (ndarray (num_movies,num_users)    : matrix of user ratings of movies
      R (ndarray (num_movies,num_users)    : matrix, where R(i, j) = 1 if the i-th movies was rated by the j-th user
      lambda_ (float): regularization parameter
    Returns:
      J (float) : Cost
    """
    f_x = tf.linalg.matmul(X, tf.transpose(W)) + b
    E = (f_x - Y)**2
    j = E*R
    J = 0.5 * tf.reduce_sum(j) + (lambda_/2) * (tf.reduce_sum(X**2) + tf.reduce_sum(W**2))
    return J

# %%
results_df = pd.read_csv("https://raw.githubusercontent.com/schubertjan/race-recommender/master/race_results.csv")
results_df = results_df.set_index("Race")
results_df
# Out:
#                                        aagaard hansen tobias  aalerud katrine  \
# Race
# 2-districtenpijl-ekeren-deurne-me                        NaN              NaN
# Eschborn-Frankfurt                                       NaN              NaN
# adriatica-ionica                                         NaN              NaN
# albani-classic-fyen-rundt                                NaN              NaN
# amstel-gold                                              NaN              NaN
# ...                                                      ...              ...
# vuelta-ciclista-a-la-region-de-murcia                    NaN              NaN
# world-championship                                       NaN              NaN
# world-championship-we                                    NaN             20.0
# youngster-coast-challenge                                NaN              NaN
# zodc-zuidenveld-tour                                     0.0              NaN
#
#                                        aalrust håkon  aalto jimi  \
# Race
# 2-districtenpijl-ekeren-deurne-me                NaN         NaN
# Eschborn-Frankfurt                               NaN         NaN
# adriatica-ionica                                 NaN         NaN
# albani-classic-fyen-rundt                        NaN         NaN
# amstel-gold                                      NaN         NaN
# ...                                              ...         ...
# vuelta-ciclista-a-la-region-de-murcia            NaN         NaN
# world-championship                               NaN         NaN
# world-championship-we                            NaN         NaN
# youngster-coast-challenge                        NaN         NaN
# zodc-zuidenveld-tour                             NaN         NaN
#
#                                        aas eirik vang  aasheim ludvig  \
# Race
# 2-districtenpijl-ekeren-deurne-me                 NaN             NaN
# Eschborn-Frankfurt                                NaN             NaN
# adriatica-ionica                                  NaN             NaN
# albani-classic-fyen-rundt                         NaN             NaN
# amstel-gold                                       NaN             NaN
# ...                                               ...             ...
# vuelta-ciclista-a-la-region-de-murcia             NaN             NaN
# world-championship                                NaN             NaN
# world-championship-we                             NaN             NaN
# youngster-coast-challenge                         NaN             NaN
# zodc-zuidenveld-tour                              NaN             NaN
#
#                                        aaskov pallesen jeppe  \
# Race
# 2-districtenpijl-ekeren-deurne-me                        NaN
# Eschborn-Frankfurt                                       NaN
# adriatica-ionica                                         NaN
# albani-classic-fyen-rundt                                NaN
# amstel-gold                                              NaN
# ...                                                      ...
# vuelta-ciclista-a-la-region-de-murcia                    NaN
# world-championship                                       NaN
# world-championship-we                                    NaN
# youngster-coast-challenge                                NaN
# zodc-zuidenveld-tour                                     NaN
#
#                                        aasvold kristian  abay burak  \
# Race
# 2-districtenpijl-ekeren-deurne-me                   NaN         NaN
# Eschborn-Frankfurt                                  NaN         NaN
# adriatica-ionica                                    NaN         NaN
# albani-classic-fyen-rundt                           NaN         NaN
# amstel-gold                                         NaN         NaN
# ...                                                 ...         ...
# vuelta-ciclista-a-la-region-de-murcia               0.0         NaN
# world-championship                                  NaN         NaN
# world-championship-we                               NaN         NaN
# youngster-coast-challenge                           NaN         NaN
# zodc-zuidenveld-tour                                NaN         NaN
#
#                                        abazi qendrim  ...  štybar zdeněk  \
# Race                                                  ...
# 2-districtenpijl-ekeren-deurne-me                NaN  ...            NaN
# Eschborn-Frankfurt                               NaN  ...            NaN
# adriatica-ionica                                 NaN  ...            NaN
# albani-classic-fyen-rundt                        NaN  ...            NaN
# amstel-gold                                      NaN  ...           20.0
# ...                                              ...  ...            ...
# vuelta-ciclista-a-la-region-de-murcia            NaN  ...            NaN
# world-championship                               NaN  ...            NaN
# world-championship-we                            NaN  ...            NaN
# youngster-coast-challenge                        NaN  ...            NaN
# zodc-zuidenveld-tour                             NaN  ...            NaN
#
#                                        šēlis jānis  ťoupalík adam  \
# Race
# 2-districtenpijl-ekeren-deurne-me              NaN            NaN
# Eschborn-Frankfurt                             NaN            NaN
# adriatica-ionica                               NaN            NaN
# albani-classic-fyen-rundt                      NaN            NaN
# amstel-gold                                    NaN            NaN
# ...                                            ...            ...
# vuelta-ciclista-a-la-region-de-murcia          NaN            NaN
# world-championship                             NaN            0.0
# world-championship-we                          NaN            NaN
# youngster-coast-challenge                      NaN            NaN
# zodc-zuidenveld-tour                           NaN            NaN
#
#                                        ťoupalík jakub  żelazowski michał  \
# Race
# 2-districtenpijl-ekeren-deurne-me                 NaN                NaN
# Eschborn-Frankfurt                                NaN                NaN
# adriatica-ionica                                  NaN                NaN
# albani-classic-fyen-rundt                         NaN                NaN
# amstel-gold                                       NaN                NaN
# ...                                               ...                ...
# vuelta-ciclista-a-la-region-de-murcia             NaN                NaN
# world-championship                                NaN                NaN
# world-championship-we                             NaN                NaN
# youngster-coast-challenge                         NaN                NaN
# zodc-zuidenveld-tour                              NaN                NaN
#
#                                        żuber adam  żurek jakub  žigart urška  \
# Race
# 2-districtenpijl-ekeren-deurne-me             NaN          NaN           NaN
# Eschborn-Frankfurt                            NaN          NaN           NaN
# adriatica-ionica                              NaN          NaN           NaN
# albani-classic-fyen-rundt                     NaN          NaN           NaN
# amstel-gold                                   NaN          NaN           NaN
# ...                                           ...          ...           ...
# vuelta-ciclista-a-la-region-de-murcia         NaN          NaN           NaN
# world-championship                            NaN          NaN           NaN
# world-championship-we                         NaN          NaN           0.0
# youngster-coast-challenge                     NaN          NaN           NaN
# zodc-zuidenveld-tour                          NaN          NaN           NaN
#
#                                        žumer matic  țvetcov serghei
# Race
# 2-districtenpijl-ekeren-deurne-me              NaN              NaN
# Eschborn-Frankfurt                             NaN              NaN
# adriatica-ionica                               NaN              NaN
# albani-classic-fyen-rundt                      NaN              NaN
# amstel-gold                                    NaN              NaN
# ...                                            ...              ...
# vuelta-ciclista-a-la-region-de-murcia          NaN              NaN
# world-championship                             NaN              NaN
# world-championship-we                          NaN              NaN
# youngster-coast-challenge                      NaN              NaN
# zodc-zuidenveld-tour                           NaN              NaN
#
# [272 rows x 5956 columns]

# %%
Y = results_df.to_numpy()
Y_norm = results_df.apply(lambda row: stand(np.log(row + 1)), axis=1).to_numpy()
Y_norm[np.isnan(Y_norm)] = -99

Y_mean = np.nanmean(np.log(Y+1), axis=1)
Y_std = np.nanstd(np.log(Y+1), axis=1)

R = np.ones(Y.shape)
R[np.isnan(Y)] = 0

# %%
#  Useful Values
num_races, num_riders = Y.shape
num_features = 100
lambda_ = 1
# Set Initial Parameters (W, X), use tf.Variable to track these variables
tf.random.set_seed(1234) # for consistent results
W = tf.Variable(tf.random.normal((num_riders,  num_features),dtype=tf.float64),  name='W')
X = tf.Variable(tf.random.normal((num_races, num_features),dtype=tf.float64),  name='X')
b = tf.Variable(tf.random.normal((1,          num_riders),   dtype=tf.float64),  name='b')

# Instantiate an optimizer.
optimizer = keras.optimizers.Adam(learning_rate=1e-1)

iterations = 1000
lambda_ = 1
for iter in range(iterations):
    # Use TensorFlow’s GradientTape
    # to record the operations used to compute the cost 
    with tf.GradientTape() as tape:

        # Compute the cost (forward pass included in cost)
        cost_value = cofi_cost_func(X, W, b, Y_norm, R, lambda_)

    # Use the gradient tape to automatically retrieve
    # the gradients of the trainable variables with respect to the loss
    grads = tape.gradient( cost_value, [X,W,b] )

    # Run one step of gradient descent by updating
    # the value of the variables to minimize the loss.
    optimizer.apply_gradients( zip(grads, [X,W,b]) )

    # Log periodically.
    if iter % 20 == 0:
        print(f"Training loss at iteration {iter}: {cost_value:0.1f}")
# Out:
# Training loss at iteration 0: 4096813.5
# Training loss at iteration 20: 210955.5
# Training loss at iteration 40: 88783.4
# Training loss at iteration 60: 49732.9
# Training loss at iteration 80: 33001.4
# Training loss at iteration 100: 24633.9
# Training loss at iteration 120: 19784.4
# Training loss at iteration 140: 16671.6
# Training loss at iteration 160: 14530.1
# Training loss at iteration 180: 12977.0
# Training loss at iteration 200: 11804.2
# Training loss at iteration 220: 10891.2
# Training loss at iteration 240: 10163.9
# Training loss at iteration 260: 9574.6
# Training loss at iteration 280: 9090.6
# Training loss at iteration 300: 8689.0
# Training loss at iteration 320: 8352.8
# Training loss at iteration 340: 8069.4
# Training loss at iteration 360: 7828.8
# Training loss at iteration 380: 7623.5
# Training loss at iteration 400: 7447.4
# Training loss at iteration 420: 7295.5
# Training loss at iteration 440: 7163.9
# Training loss at iteration 460: 7049.4
# Training loss at iteration 480: 6949.4
# Training loss at iteration 500: 6861.7
# Training loss at iteration 520: 6784.5
# Training loss at iteration 540: 6716.3
# Training loss at iteration 560: 6655.8
# Training loss at iteration 580: 6602.0
# Training loss at iteration 600: 6554.1
# Training loss at iteration 620: 6511.2
# Training loss at iteration 640: 6472.7
# Training loss at iteration 660: 6438.1
# Training loss at iteration 680: 6406.9
# Training loss at iteration 700: 6378.8
# Training loss at iteration 720: 6353.3
# Training loss at iteration 740: 6330.1
# Training loss at iteration 760: 6309.1
# Training loss at iteration 780: 6289.9
# Training loss at iteration 800: 6272.5
# Training loss at iteration 820: 6256.5
# Training loss at iteration 840: 6241.9
# Training loss at iteration 860: 6228.5
# Training loss at iteration 880: 6216.2
# Training loss at iteration 900: 6204.9
# Training loss at iteration 920: 6194.5
# Training loss at iteration 940: 6184.9
# Training loss at iteration 960: 6176.0
# Training loss at iteration 980: 6167.8

# %%
# Make a prediction using trained weights and biases
p = np.matmul(X.numpy(), np.transpose(W.numpy())) + b.numpy()

#restore the mean
pm_e = np.multiply(p, Y_std.reshape(p.shape[0], 1)) + Y_mean.reshape(p.shape[0], 1)
pm = np.exp(pm_e)-1

# %%
rider_name = "kristoff alexander"
j = results_df.columns.isin([rider_name])
rider = np.arange(0, results_df.shape[1])[j]

check = pd.DataFrame(data={"y_hat": pm[:, rider].reshape(-1,), "y": results_df.iloc[:, rider].values.reshape(-1,)}, index = results_df.index)
check.dropna()
# Out:
#                                             y_hat           y
# Race
# Eschborn-Frankfurt                     184.609912  215.000000
# clasica-de-almeria                     119.443921  150.000000
# dauphine                                 0.095111    0.000000
# deia-trophy                             44.002400   50.000000
# dwars-door-vlaanderen                   51.435339   60.000000
# e3-harelbeke                             0.443489    0.000000
# gent-wevelgem                           38.386694   40.000000
# gp-du-canton-d-argovie                   0.116388    0.000000
# gp-jef-scherens                         59.775953   70.000000
# kuurne-brussel-kuurne                  102.994396  125.000000
# milano-sanremo                           6.745636    6.666667
# milano-torino                            0.183765    0.000000
# omloop-het-nieuwsblad                    1.224437    1.000000
# oxyclean-classic-brugge-de-panne        12.112013   12.000000
# paris-nice                               0.077126    0.000000
# paris-roubaix                           49.661454   50.000000
# ronde-van-vlaanderen                   130.722102  146.666667
# tirreno-adriatico                        0.065433    0.000000
# tour-de-france                          83.267020   87.500000
# tour-de-suisse                           9.511036   10.000000
# trofeo-alcudia                           0.126774    0.000000
# trofeo-calvia                            0.139994    0.000000
# trofeo-palma                             4.941676    5.000000
# volta-ao-algarve                         0.023178    0.000000
# vuelta-a-la-comunidad-valenciana         4.808025    5.000000
# vuelta-ciclista-a-la-region-de-murcia    2.895155    3.000000

# %%
from google.colab import files

pd.DataFrame(pm, index = results_df.index, columns=results_df.columns, dtype = int).to_csv("y_hat.csv", index=True)

files.download('y_hat.csv')
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: FutureWarning: In a future version, passing float-dtype values and an integer dtype to DataFrame will retain floating dtype if they cannot be cast losslessly (matching Series behavior). To retain the old behavior, use DataFrame(data).astype(dtype)
#   This is separate from the ipykernel package so we can avoid doing imports until
